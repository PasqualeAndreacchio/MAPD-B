# %% [markdown]
# # RDBMS - MySQL
#
# ## 00 - Introduction
#
# Among the Relational DBMSs, the most widely known are Oracle, SQLite, Postgres, MariaDB, and MySQL.
#
# Each one of them is characterized by a different set of "variations" on top of the base SQL language, although usually minor.
#
# We will use **MySQL** to run exercises about Relational DB transactions using the SQL language, as it is *currently* among the top of the list of most widely used RDBMSs.
#
# [DB Engines Ranking Trend](https://db-engines.com/en/ranking_trend/relational+dbms)
#
# [Stack Overflow 2025 Developer Survey - Most Popular Technologies (Language)](https://survey.stackoverflow.co/2025/technology#most-popular-technologies-language)
#
# [Stack Overflow 2025 Developer Survey - Most Popular Technologies (Database)](https://survey.stackoverflow.co/2025/technology#most-popular-technologies-database)

# %% [markdown]
# MySQL programming interfaces exist for many languages, including C, C++, Go, Java, Perl, PHP, Python, etc...
#
# Even simply referring to Python, we can count on several options to connect and interact with the DBs.
#
# Let's explore a couple of them...

# %% [markdown]
# ## 01 - Create a Connection to MySQL
#
# A MySQL server is running within one of your Docker containers.
#
# You can access it using the MySQL server credentials defined in the `docker-compose.yml` file.
#
# By default, a `root` user is created with the following credentials:
# - **Username:** `root`
# - **Password:** `root_pwd`
#
# Additionally, a non-`root` user is created by default with:
# - **Username:** `my_user`
# - **Password:** `my_pwd`

# %% [markdown]
# #### Interactive
#
# To interact with the MySQL server, you can log in interactively to its Docker container.
#
# First, check the `CONTAINER ID` of the container named `mysql_db` by running:
#
# ```bash
# $ docker ps
# ```
#
# Then, initiate an interactive bash session within the container by executing:
#
# ```bash
# $ docker exec -it <YOUR CONTAINER ID> bash
# ```
#
# Once inside the container, you can access the MySQL server as if you were connected to a remote server hosting your databases:
#
# ```bash
# $ mysql -u <EITHER ROOT OR USER> -p
# ```
#
# Replace `<YOUR CONTAINER ID>` with the actual container ID obtained from the `docker ps` command output, and `<EITHER ROOT OR USER>` with either `root` or `my_user`, depending on the user you want to log in as.

# %% [markdown]
# We can then inspect the MySQL server to display all databases by executing the following SQL command:
#
# ```mysql
# SHOW DATABASES;
# ```
#
# **NB**: Remember to end a SQL command with a semicolon `;`.

# %% [markdown]
# #### mysql.connector
#
# A more pythonic way to interact with a MySQL server is by using a dedicated driver such as `mysql.connector`, which is already installed in the Jupyter Notebook container.
#
# This connector offers an interface to establish a connection object to the MySQL server and provides various functionalities for executing transactions and fetching records from databases.
#
# We can start by declaring a connection to our MySQL server.
#
# **NB:** The server is hosted in a different container from the notebook, simulating a connection between two different machines: a client and a server.

# %%
# import the connector
import mysql.connector

# declare a connection to the MySQL server 
# the hostname (or IP) of the server machine should be passed
db = mysql.connector.connect(
  user="root",
  password="root_pwd",
  host="db", # in this case 'db' is the equivalent of the IP address of the server 
             # or 'localhost' if running mysql locally
)

print(db)
# Out:
# <mysql.connector.connection_cext.CMySQLConnection object at 0x762125b10ec0>

# %% [markdown]
# At this point, a database connection is established.
#
# To interact with the database using Python and `mysql.connector`, we need a "handle" known as a cursor, which must be instantiated.
#
# When using this connector to interact with the database, all SQL statements are executed using the cursor.

# %%
# create our db cursor object
dbc = db.cursor()

# %% [markdown]
# The cursor allows us to execute all SQL transactions on the database as if we were logged into the server.
#
# If a transaction fetches results from the database (returns a set of records), the connector object will retain the results. This feature can be useful for later use in a more "pythonic" way, integrating our database queries with other Python statements.
#
# The syntax for issuing a generic SQL statement is as follows:
#
# ```python
# connector_object.execute(my_sql_query)
# ```
#
# For example, let's execute the same check as before by asking MySQL to show us all available databases...

# %%
# show all available databases
dbc.execute(
"SHOW DATABASES"
)

# %% [markdown]
# No output is printed because the result of this SQL transaction is collected into the cursor as a list of records (tuples).
#
# To retrieve the results, we can simply loop over them.

# %%
# loop over the container to fetch the results
for _ in dbc:
    print(_)
# Out:
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('sys',)

# %% [markdown]
# If we are `root` users in this example, we can access the inner structure of the MySQL server, which already contains a few databases by default.
#
# After fetching the output of the transaction, the cursor reaches "the end" of the records and becomes available to perform a new transaction.

# %%
# use fetch to retrieve one, many, or all entries in the cursor
# dbc.fetchone()

dbc.fetchmany(2)

# dbc.fetchall()
# Out:
# []

# %%
dbc.reset()

# %% [markdown]
# If one wants to perform a new transaction without collecting the output of the previous one from the cursor, a reset must be issued first:
#
# ```python
# connector_object.reset()
# ```

# %% [markdown]
# If a generic user (i.e., not the `root` user) is logged into the database server, they will not have access to certain functionalities and won't be able to see the previous list of all databases.
#
# Some of these databases and tables are protected and used to store additional information about the state of the MySQL server and the connected users.

# %%
# connecto to the database as a non-root user
udb = mysql.connector.connect(
  user="my_user",
  password="my_pwd",
  host="db",
)

# create a cursor
udbc = udb.cursor()

# execute the transaction
udbc.execute(
"SHOW DATABASES"
)

# fetch all results
udbc.fetchall()
# Out:
# [('information_schema',), ('performance_schema',)]

# %% [markdown]
# #### iPython Magic
#
# Another way to execute queries from Python within a Jupyter Notebook is by utilizing notebook "magic" functions, which are based on iPython and SQLAlchemy.
#
# This approach is similar to loading inline figures from Matplotlib using `%matplotlib inline`.
#
# To instruct iPython to interpret SQL commands and connect to the appropriate database, we need to:
#
# 1. Load the extension for the SQL language.
# 2. Set the environment variable to point to the connection to the database.

# %%
# %load_ext sql

# %env DATABASE_URL=mysql+mysqlconnector://root:root_pwd@db
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'
# Out:
# env: DATABASE_URL=mysql+mysqlconnector://root:root_pwd@db

# %% [markdown]
# Now, notebook cells can execute SQL transactions directly in plain SQL by starting the cell with `%%sql`.
#
# By default, the result is also printed using the `pretty` format, similar to the pandas-like format.

# %%
# %%sql
#
# SHOW DATABASES;
# Out:
# 4 rows affected.
# [('information_schema',), ('mysql',), ('performance_schema',), ('sys',)]

# %% [markdown]
# An additional benefit is that a single `%sql` (not a double `%%sql`) can be used to combine a SQL query with any Python command.

# %%
my_python_var = %sql SHOW DATABASES

print(my_python_var)
print(f'First record={my_python_var[0]}')
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# +--------------------+
# |      Database      |
# +--------------------+
# | information_schema |
# |       mysql        |
# | performance_schema |
# |        sys         |
# +--------------------+
# First record=('information_schema',)

# %% [markdown]
# The combination of either of the two Pythonic methods can be used to easily redirect the output of database transactions to leverage other well-known Python modules, such as plotting with Matplotlib.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.hist(my_python_var);
plt.xticks(rotation='vertical');

# %% [markdown]
# ## 02 Database and Table creation

# %% [markdown]
# We have already seen how to inspect the server to see which databases are present using the command:
#
# ```mysql
# SHOW DATABASES;
# ```
#
# To start interacting with a specific database, we can select it using `USE`:
#
# ```mysql
# USE <DB_NAME>;
# ```
#
# If the user has been granted the right to access this database, it's possible to start investigating its content.

# %% [markdown]
# If we want to create a new database to work with instead, we can use the command:
#
# ```mysql
# CREATE DATABASE <DB_NAME>;
# ```
#
# A more complex syntax can be used to create a new database only if no other database with the same name already exists:
#
# ```mysql
# CREATE DATABASE IF NOT EXISTS <DB_NAME>;
# ```

# %% [markdown]
# - Check if a DB named `my_db` exists.
# - If not, create one.
# - Then, switch to the new DB to start using it.

# %%
# %%sql
#
# CREATE DATABASE IF NOT EXISTS my_db;
# USE my_db;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# 0 rows affected.
# []

# %% [markdown]
# All tables contained in the DB are shown in a similar way to what used to show all DBs on the server:
#
# ```mysql
# SHOW TABLES;
# ```
#
# **NB**: we are inspecting the content of a specific DB (the one selected with `USE <DB_NAME>`)

# %%
# %%sql
#
# SHOW TABLES;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %% [markdown]
# The analogous Pythonic way to execute the same list of commands (using the `mysql.connector` driver) is the following:
#
# **NB**: This time we are not retrieving results from the server, but are instead asking the DBMS to _create_ a new database. We are issuing a request that requires us to **commit** a change in the MySQL server

# %%
# defining the sql command line
sql_ = "CREATE DATABASE IF NOT EXISTS my_db;"

# instructing the cursor to execute it
dbc.execute(sql_)

# in this case the result of the sql transaction is not to return a list of items 
# it is instead a change in the DB structure
# therefore, for the change to have an effect, the change is to be committed to the DB
db.commit()

# %% [markdown]
# All other commands discussed so far (`USE` and `SHOW`), do not require any change to be committed, therefore we can simply issue them via the cursor.
#
# Creating new databases, or changing the structure (_schema_) or the content (_instance_) of a database, will instead require a `commit`.

# %%
# use the my_db database
dbc.execute("USE my_db")

# show all tables
dbc.execute("SHOW TABLES")
dbc.fetchall()
# Out:
# []

# %% [markdown]
# So far the `my_db` database is empty, so let's use the same lines presented in the slides to create a dummy `Users` table.
#
# Any table can then be inspected to check its schema by listing all attributes.
#
# 1. Begin by creating a `Users` table. Define the schema by specifying each attribute.
# 2. Verify if it has been successfully created in the database. Use the `SHOW` command for this purpose.
# 3. Inspect the schema of the `Users` table, execute the `DESCRIBE <TABLE_NAME>` command.

# %%
# %%sql
#
# # create a table following the schema on the slides
# CREATE TABLE Users (
#     UserID    varchar(30),
#     BadgeNum  int(16),
#     FirstName varchar(255),
#     LastName  varchar(255),
#     Age       int,
#     OtherAttr float
# );
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # show the tables in the current database
# SHOW TABLES;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [('Users',)]

# %%
# %%sql
#
# # describe the table `Users`
# DESCRIBE Users;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 6 rows affected.
# [('UserID', 'varchar(30)', 'YES', '', None, ''),
#  ('BadgeNum', 'int', 'YES', '', None, ''),
#  ('FirstName', 'varchar(255)', 'YES', '', None, ''),
#  ('LastName', 'varchar(255)', 'YES', '', None, ''),
#  ('Age', 'int', 'YES', '', None, ''),
#  ('OtherAttr', 'float', 'YES', '', None, '')]

# %% [markdown]
# Following the previous examples, let's perform the same transactions using the `mysql.connector` driver. Since the `Users` table already exists, we will create a new table called `Users_py`.
#
# Remember the following points:
#
# - Utilize the DB Cursor to execute the transactions.
# - Transactions that change the content of the DB must be _committed_ to the DB.
# - Transactions returning the content of the DB host their results _in the cursor_.

# %%
# create a table following the schema on the slides
sql = 'CREATE TABLE Users_py (\
       UserID    varchar(30),\
       BadgeNum  int(16),\
       FirstName varchar(255),\
       LastName  varchar(255),\
       Age       int,\
       OtherAttr float);'
dbc.execute(sql)
db.commit()

# %%
# show the tables in the current database
dbc.execute("SHOW TABLES")
dbc.fetchall()
# Out:
# [('Users',), ('Users_py',)]

# %%
# describe the table `Users_py`
dbc.execute("DESCRIBE Users_py")
dbc.fetchall()
# Out:
# [('UserID', 'varchar(30)', 'YES', '', None, ''),
#  ('BadgeNum', 'int', 'YES', '', None, ''),
#  ('FirstName', 'varchar(255)', 'YES', '', None, ''),
#  ('LastName', 'varchar(255)', 'YES', '', None, ''),
#  ('Age', 'int', 'YES', '', None, ''),
#  ('OtherAttr', 'float', 'YES', '', None, '')]

# %% [markdown]
# ## 03 Declaring constraints and altering tables

# %% [markdown]
# Before moving on, let's clean up all existing tables in our database.
#
# To remove an existing table from the database, you can use the following instruction:
#
# ```mysql
# DROP TABLE IF EXISTS <NAME OF YOUR TABLE>;
# ```
#
# **CAUTION**: Dropping a table deletes all records from that table and severs all connections with other tables based on foreign keys. This action can render the entire database unusable. Be extremely careful when executing this command.

# %%
# %%sql
#
# # drop the table Users
# DROP TABLE IF EXISTS Users;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %% [markdown]
# Let's also drop the `Users_py` table using the Python connector.
# This is once again an action that alters the database, thus we must `commit` it.

# %%
# drop the table Users_py
dbc.execute("DROP TABLE IF EXISTS Users_py")
db.commit()

# %%
# inspect the content of the database
dbc.execute("SHOW TABLES")
dbc.fetchall()
# Out:
# []

# %% [markdown]
# Create a new `products` table with the following schema:
#
# | Attribute    | Type    | Extra info | Constraint                |
# |--------------|---------|------------|---------------------------|
# | productID    | Integer |            | NOT NULL AUTO_INCREMENT  |
# | productName  | String  | Max length 30 | DEFAULT ''            |
# | unitPrice    | Float   |            | NOT NULL DEFAULT 99999.99|
# | unitsInStock | Integer | Unsigned   | NOT NULL DEFAULT 0        |
#
#
# The `productID` attribute will be our `PRIMARY KEY`.
#
# This can be declared either inline, or at the end of the table definition:
#
# ```mysql
# productID INT NOT NULL UNIQUE AUTO_INCREMENT PRIMARY KEY
# ```
#
# or
#
# ```mysql
# productID INT NOT NULL UNIQUE AUTO_INCREMENT
# [...]
# PRIMARY KEY (productID)
# ```

# %%
# %%sql
#
# # create the products table
# CREATE TABLE IF NOT EXISTS products (
#          productID    INT          NOT NULL UNIQUE AUTO_INCREMENT PRIMARY KEY,
#          productName  VARCHAR(30)  DEFAULT '' ,
#          unitPrice    FLOAT        NOT NULL DEFAULT 99999.99,
#          unitsInStock INT UNSIGNED NOT NULL DEFAULT 0
# );
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # inspect the table schema
# DESCRIBE products;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [('productID', 'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('productName', 'varchar(30)', 'YES', '', '', ''),
#  ('unitPrice', 'float', 'NO', '', '100000', ''),
#  ('unitsInStock', 'int unsigned', 'NO', '', '0', '')]

# %% [markdown]
# The table does not contain any constraints, default values, or foreign keys.
#
# The **schema** of a given table can be altered by adding/removing Attributes, as well as by adding constraints.
#
# Let's first add a new attribute to the table:
#
# | Attribute       | Type    | Extra info     | Constraint                |
# |-----------------|---------|----------------|---------------------------|
# | productID       | Integer |                | NOT NULL AUTO_INCREMENT  |
# | productName     | String  | Max length 30  | DEFAULT ''               |
# | unitPrice       | Float   |                | NOT NULL DEFAULT 99999.99|
# | unitsInStock    | Integer | Unsigned       | NOT NULL DEFAULT 0       |
# | **isDiscontinued** | **Bool** |              | NOT NULL                  |
#
#
# To alter the **schema** of a table and create a new column we can act on it with:
#
# ```mysql
# ALTER TABLE <THE TABLE>
# ADD COLUMN <NEW COL> <THE NEW ATTRIBUTE DECLARATION>;
# ```

# %% [markdown]
# #### Alter the `products` table and add the `isDiscontinued` attribute

# %%
# %%sql
#
# # alter the table
# ALTER TABLE products
# ADD COLUMN isDiscontinued BOOL NOT NULL;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # inspect the table schema
# DESCRIBE products;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('productID', 'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('productName', 'varchar(30)', 'YES', '', '', ''),
#  ('unitPrice', 'float', 'NO', '', '100000', ''),
#  ('unitsInStock', 'int unsigned', 'NO', '', '0', ''),
#  ('isDiscontinued', 'tinyint(1)', 'NO', '', None, '')]

# %% [markdown]
# The `isDiscontinued` attribute does not contain any meaningful constraint or default value.
# Let's consider `0` as a good default value for this attribute:
#
# | Attribute | Type | Extra info | Constraint |
# | --- | --- | --- |--- |
# | productID   | Integer | | NOT NULL AUTO_INCREMENT |
# | productName | String | Max length 30 | DEFAULT '' |
# | unitPrice   | Float | | NOT NULL DEFAULT 99999.99|
# | unitsInStock | Integer | Unsigned | NOT NULL DEFAULT 0 |
# | isDiscontinued  | Bool | | NOT NULL **DEFAULT 0** |
#
# We can use the same `ALTER TABLE` instruction to do this, and set a new default:
#
# ```mysql
# ALTER TABLE <THE TABLE>
# ALTER <ATTRIBUTE> SET DEFAULT <NEW DEFAULT>;
# ```

# %%
# %%sql
#
# # alter the table
# ALTER TABLE products
# ALTER isDiscontinued SET DEFAULT 0;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # inspect the table schema
# DESCRIBE products;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('productID', 'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('productName', 'varchar(30)', 'YES', '', '', ''),
#  ('unitPrice', 'float', 'NO', '', '100000', ''),
#  ('unitsInStock', 'int unsigned', 'NO', '', '0', ''),
#  ('isDiscontinued', 'tinyint(1)', 'NO', '', '0', '')]

# %% [markdown]
# We can also impose `productName` to be not-null by altering the table one final time.
#
# | Attribute | Type | Extra info | Constraint |
# | --- | --- | --- |--- |
# | productID   | Integer | | NOT NULL AUTO_INCREMENT |
# | productName | String | Max length 30 | **NOT NULL** DEFAULT '' |
# | unitPrice   | Float | | NOT NULL DEFAULT 99999.99|
# | unitsInStock | Integer | Unsigned | NOT NULL DEFAULT 0 |
# | isDiscontinued  | Bool | | NOT NULL DEFAULT 0 |
#
#
# In MySQL, this implies modifying the entire attribute, thus the Type will have to be re-stated:
#
# ```mysql
# ALTER TABLE <THE TABLE>
# MODIFY <ATTRIBUTE> <ATTRIBUTE TYPE> <CONSTRAINT>;
# ```

# %%
# %%sql
#
# # alter the table
# ALTER TABLE products
# MODIFY productName VARCHAR(30) NOT NULL;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # inspect the table schema
# DESCRIBE products;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('productID', 'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('productName', 'varchar(30)', 'NO', '', None, ''),
#  ('unitPrice', 'float', 'NO', '', '100000', ''),
#  ('unitsInStock', 'int unsigned', 'NO', '', '0', ''),
#  ('isDiscontinued', 'tinyint(1)', 'NO', '', '0', '')]

# %% [markdown]
# Let's now create a `suppliers` table with the following description:
#
# | Attribute | Type | Extra info | Constraint |
# | --- | --- | --- |--- |
# | supplierID   | Integer | | NOT NULL AUTO_INCREMENT |
# | supplierName | String | Max length 30 | NOT NULL DEFAULT "" |
# | countryCode   | Char | Length 3 | NOT NULL |
# | email   | String | Max length 30  | NOT NULL |
#
# `supplierID` is going to act as the table's primary key in this case.

# %%
# %%sql
#
# # create the suppliers table
# CREATE TABLE suppliers (
#     supplierID      INT NOT NULL UNIQUE AUTO_INCREMENT PRIMARY KEY,
#     supplierName    VARCHAR(30) NOT NULL DEFAULT "",
#     countryCode     CHAR(3) NOT NULL,
#     email           VARCHAR(30) NOT NULL
# );
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # inspect the table schema
# DESCRIBE suppliers;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [('supplierID', 'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('supplierName', 'varchar(30)', 'NO', '', '', ''),
#  ('countryCode', 'char(3)', 'NO', '', None, ''),
#  ('email', 'varchar(30)', 'NO', '', None, '')]

# %% [markdown]
# Alter the table to include a default "ITA" for `countryCode`

# %%
# %%sql
#
# # alter the table
# ALTER TABLE suppliers
# ALTER countryCode SET DEFAULT "ITA";
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # inspect the table schema
# DESCRIBE suppliers;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [('supplierID', 'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('supplierName', 'varchar(30)', 'NO', '', '', ''),
#  ('countryCode', 'char(3)', 'NO', '', 'ITA', ''),
#  ('email', 'varchar(30)', 'NO', '', None, '')]

# %% [markdown]
# To establish a relation between the `products` and `suppliers` tables, we have to consider that:
#
# - a supplier can supply multiple products
# - a product can be supplied by multiple suppliers
#
# This is a **many-to-many** relationship, which requires a supporting external table.
#
# To establish a many-to-many relationship between the products and suppliers tables, we create a junction table named `supplier_to_product` with foreign keys referencing the `productID` from the `products` table and the `supplierID` from the `suppliers` table.
#
# Create a new `supplier_to_product` table with the following attributes:
#
# | Attribute | Type | Extra info | Constraint |
# | --- | --- | --- |--- |
# | prodID   | Integer | | NOT NULL |
# | supID    | Integer | | NOT NULL |

# %%
# %%sql
#
# # create the support table
# CREATE TABLE supplier_to_product (
#     prodID     INT NOT NULL,
#     supID      INT NOT NULL
# );
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %% [markdown]
# Neither `prodID` nor `supID` is a good primary key in this case, as we can have both appearing multiple times in the table.
#
# However, a good primary key for this table is the combination `(prodID,supID)` which is unique, and thus, a good key.
#
# We can alter the table to add the primary key statement:
#
# ```mysql
# ALTER TABLE <TABLE>
# ADD PRIMARY KEY (<ATTRIBUTE 1>, <ATTRIBUTE 2>);
# ```

# %%
# %%sql
#
# # alter the table
# ALTER TABLE supplier_to_product
# ADD PRIMARY KEY (prodID, supID);
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # inspect the table schema
# DESCRIBE supplier_to_product;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [('prodID', 'int', 'NO', 'PRI', None, ''),
#  ('supID', 'int', 'NO', 'PRI', None, '')]

# %% [markdown]
# Finally, we can link the 3 tables together by stating which attributes act as the foreign keys in the `supplier_to_product` table, and to which attributes in the parent tables they refer to.
#
# - `prodID` points to the `productID` attribute of `products` table
# - `supID` points to the `supplierID` attribute of `supplier` table
#
# This translates into:
# - `prodID` is a foreign key for `supplier_to_product`
# - `subID` is a foreign key for `supplier_to_product`
# - the combination `(prodID, supID)` is the primary key of `supplier_to_product`
#
# We can declare an attribute as a foreign key by altering the table:
#
# ```mysql
# ALTER TABLE <TABLE>
# ADD FOREIGN KEY (<ATTRIBUTE IN THIS TABLE>) REFERENCES <OTHER TABLE>(<ATTRIBUTE IN OTHER TABLE>);
# ```

# %%
# %%sql
#
# # alter the table
# ALTER TABLE supplier_to_product
# ADD CONSTRAINT FK_prod
# FOREIGN KEY (prodID) REFERENCES products(productID);
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # alter the table
# ALTER TABLE supplier_to_product
# ADD CONSTRAINT FK_sup
# FOREIGN KEY (supID) REFERENCES suppliers(supplierID);
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # inspect the table schema
# DESCRIBE supplier_to_product;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [('prodID', 'int', 'NO', 'PRI', None, ''),
#  ('supID', 'int', 'NO', 'PRI', None, '')]

# %% [markdown]
# ## 04 Inserting Updating and Deleting records

# %% [markdown]
# The tables are currently empty.
# We can inspect their content by performing a simple "read" query using `SELECT`.
# We will discuss later the full syntax of the `SELECT` statement... for the time being, it's important to realize that this command will show the entire content of all columns of the table we are inspecting.
#
# ```mysql
# SELECT * FROM <TABLE>;
# ```
#
# To insert a single record into a table we can proceed in either of the two following ways:
#
# 1. By explicitly specifying the names of the columns when passing the tuple containing the values
# ```mysql
# INSERT INTO <TABLE> (<COLUMN1>, <COLUMN2>, <COLUMN3>, ...)
# VALUES (<VALUE1>, <VALUE2>, <VALUE3>, ...);
# ```
# This will work also in the case attributes with a default value will not be explicitly passed
#
#
# 2. By implicitly using all the columns when passing the tuple containing the values
# ```mysql
# INSERT INTO <TABLE>
# VALUES (<VALUE1>, <VALUE2>, ..., <VALUEn>);
# ```
#
# **NB**: 1. is the usually recommended way to perform a data insertion in SQL, as (pretty much always in coding) **explicit is better than implicit**

# %% [markdown]
# Using the `mysql.connector` we can formulate the same data insertion in a more Pythonic way, e.g. to include this statement programmatically into a loop or a function call:
#
# ```python
# sql_ = "INSERT INTO <TABLE> (<COLUMN1>, <COLUMN2>, <COLUMN3>, ...) VALUES (%s, %s, %s, ...)"
# val_ = (<VALUE1>, <VALUE2>, <VALUE3>, ...)
# db_cursor.execute(sql_, val_)
# db.commit()
# ```
#
# Being an active change to the database instance, remember to commit the insert.

# %% [markdown]
# #### Perform a simple data insertion
#
# - Verify that the product table is actually empty.
# - Insert the following list of products into the `products` table.
# - Check the content of the table after the transaction to verify that both the `AUTO_INCREMENT` key and the default values have been taken into account.
#
# | productName | unitPrice | unitsInStock | isDiscontinued |
# | --- | --- | --- |--- |
# | "Founders Porter" | 4.9 | 12 | 0 |

# %%
# %%sql
#
# # retrieve the content of the table
# DESCRIBE products;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('productID', 'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('productName', 'varchar(30)', 'NO', '', None, ''),
#  ('unitPrice', 'float', 'NO', '', '100000', ''),
#  ('unitsInStock', 'int unsigned', 'NO', '', '0', ''),
#  ('isDiscontinued', 'tinyint(1)', 'NO', '', '0', '')]

# %%
# %%sql
#
# # retrieve the content of the table
# SELECT * FROM products;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # insert records into the table
# INSERT INTO products (productName, unitPrice, unitsInStock)
# VALUES ('Founders Porter',4.9 ,12);
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# []

# %%
# %%sql
#
# # retrieve the content of the table
# SELECT * FROM products;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [(1, 'Founders Porter', 4.9, 12, 0)]

# %% [markdown]
# Multi-values insert can be performed in a similar way by separating multiple tuples with a comma:
#
# ```mysql
# INSERT INTO <TABLE> (<COLUMN1>, <COLUMN2>, <COLUMN3>, ...)
# VALUES
# (<VALUE11>, <VALUE12>, <VALUE13>, ...),
# (<VALUE21>, <VALUE22>, <VALUE23>, ...),
# (<VALUE31>, <VALUE32>, <VALUE33>, ...);
# ```
#
#
# The Python-based command is similar to the previous one, but it drops the `execute` in favor of `executemany`, using a list of tuples as values:
#
# ```python
# sql_ = "INSERT INTO <TABLE> (<COLUMN1>, <COLUMN2>, <COLUMN3>, ...) VALUES (%s, %s, %s, ...)"
# val_ = [
#     (<VALUE11>, <VALUE12>, <VALUE13>, ...),
#     (<VALUE21>, <VALUE22>, <VALUE23>, ...),
#     (<VALUE31>, <VALUE32>, <VALUE33>, ...) ]
# db_cursor.executemany(sql_, val_)
# db.commit()
# ```

# %% [markdown]
# Add a few more products to the `product` table:
#
# | productName | unitPrice | unitsInStock | isDiscontinued |
# | --- | --- | --- |--- |
# | "Punk IPA" | 5.2 | 45 |  |
# | "HB Dunkel" | 4.5 | 250 |  |
# | "Forst Xmas " | 8.0 | 2 |  |
# | "Damm Complot " | 3.7 | 120 |  |

# %%
# insert records into the table
sql_ = "INSERT INTO products (productName, unitPrice, unitsInStock) VALUES (%s, %s, %s)"
val_ = [
    ('Punk IPA',     5.2,  45),
    ('HB Dunkel',    4.5, 250),
    ('Forst Xmas',   8.0,   2),
    ('Damm Complot', 3.7, 120)]
dbc.executemany(sql_, val_)
db.commit()
     
dbc.execute("SELECT * FROM products"); 
dbc.fetchall()
# Out:
# [(1, 'Founders Porter', 4.9, 12, 0),
#  (2, 'Punk IPA', 5.2, 45, 0),
#  (3, 'HB Dunkel', 4.5, 250, 0),
#  (4, 'Forst Xmas', 8.0, 2, 0),
#  (5, 'Damm Complot', 3.7, 120, 0)]

# %% [markdown]
# Updating entries is a delicate issue in databases, as we can potentially modify all records associated with a number of conditions. This makes the update operation quite powerful and possibly error-prone if not performed with extreme caution.
#
# ```mysql
# UPDATE <TABLE>
# SET <ATTRIBUTE> = <NEW VALUE>
# WHERE <CONDITION>;
# ```
#
# or
#
# ```python
# sql_ = "UPDATE <TABLE> SET <ATTRIBUTE> = <NEW VALUE> WHERE <CONDITION>"
# db_cursor.execute(sql)
# db.commit()
#
# ```
#
# #### Let's update a single record with a "very explicit" condition statement:
#
# - Assign `isDiscontinued` equal to `1` to the "Forst Xmas" product.
# - Check if the update has taken place.

# %%
# %%sql
#
# # update the content of the table
# UPDATE products
# SET isDiscontinued = 1
# WHERE productName = "Forst Xmas";
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# []

# %%
# %%sql
#
# SELECT * FROM products;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [(1, 'Founders Porter', 4.9, 12, 0),
#  (2, 'Punk IPA', 5.2, 45, 0),
#  (3, 'HB Dunkel', 4.5, 250, 0),
#  (4, 'Forst Xmas', 8.0, 2, 1),
#  (5, 'Damm Complot', 3.7, 120, 0)]

# %% [markdown]
# Similarly, deleting entries is quite risky if not done with plenty of caution, as a wrong `WHERE` condition might inadvertently lead to the deletion of a large part of your database records.
#
# Remember, with `DELETE`, we remove entire records (i.e., tuples) from the database, not just the content of the `WHERE` conditional statement.
#
# ```mysql
# DELETE FROM <TABLE>
# WHERE <CONDITION>;
# ```
#
# or
#
# ```python
# sql_ = "DELETE FROM <TABLE> WHERE <CONDITION>"
# db_cursor.execute(sql)
# db.commit()
#
# ```
#
# #### Delete all records under a set of conditions:
#
# - Delete all products whose name begins with 'F' and ends with 's'.
# - Check if the deletion has taken place.

# %%
# %%sql
#
# # delete records from the table
# DELETE FROM products
# WHERE productName LIKE "F%s";
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# []

# %%
# %%sql
#
# # retrieve the content of the table
# SELECT * FROM products;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [(1, 'Founders Porter', 4.9, 12, 0),
#  (2, 'Punk IPA', 5.2, 45, 0),
#  (3, 'HB Dunkel', 4.5, 250, 0),
#  (5, 'Damm Complot', 3.7, 120, 0)]

# %% [markdown]
# #### Populate the `suppliers` table according to the following list
#
# | supplierName | countryCode | email|
# | --- | --- | ---|
# | "A hop in the park" | "USA" | "contactme@ahop.com" |
# | "Allez Hops! Cave à bièr" | "FRA" | "itsme@allezhops.com" |
# | "Wild Hops " | "ITA" | "myemail@wildhops.it" |
# |"Beer Paradise"|"ITA"|"beer@beerparadise.it"|

# %%
# %%sql
#
# # insert records into the table
# INSERT INTO suppliers (supplierName, countryCode, email) VALUES
# ("A hop in the park","USA","contactme@ahop.com"),
# ("Allez Hops! Cave à bièr","FRA","itsme@allezhops.com"),
# ("Wild Hops","ITA","myemail@wildhops.it"),
# ("Beer Paradise","ITA","beer@beerparadise.it");
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# []

# %%
# %%sql
#
# # retrieve the content of the table
# SELECT * FROM suppliers;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [(1, 'A hop in the park', 'USA', 'contactme@ahop.com'),
#  (2, 'Allez Hops! Cave à bièr', 'FRA', 'itsme@allezhops.com'),
#  (3, 'Wild Hops', 'ITA', 'myemail@wildhops.it'),
#  (4, 'Beer Paradise', 'ITA', 'beer@beerparadise.it')]

# %% [markdown]
# Complete the database with the two additional steps:
#
# - Update the "A hop in the park" email address to "anewemail@ahop.com"
# - Populate the table of connections between products and suppliers
#     - Remember that the `supplier_to_product` table is linked to the other two via the respective Foreign Keys
#
# | supplier | products provided |
# | --- | --- |
# | "A hop in the park" | "Punk IPA", "HB Dunkel" |

# %%
sql_ = "UPDATE suppliers SET email = %s WHERE supplierName LIKE %s;"
val_ = ('anewemail@ahop.com', 'A hop%')
dbc.execute(sql_, val_)
db.commit()
     
dbc.execute("SELECT * FROM suppliers"); 
for _ in dbc:
     print(_)
# Out:
# (1, 'A hop in the park', 'USA', 'anewemail@ahop.com')
# (2, 'Allez Hops! Cave à bièr', 'FRA', 'itsme@allezhops.com')
# (3, 'Wild Hops', 'ITA', 'myemail@wildhops.it')
# (4, 'Beer Paradise', 'ITA', 'beer@beerparadise.it')

# %%
# %%sql
#
# SELECT * FROM products;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [(1, 'Founders Porter', 4.9, 12, 0),
#  (2, 'Punk IPA', 5.2, 45, 0),
#  (3, 'HB Dunkel', 4.5, 250, 0),
#  (5, 'Damm Complot', 3.7, 120, 0)]

# %%
# %%sql
#
# SELECT * FROM suppliers;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [(1, 'A hop in the park', 'USA', 'anewemail@ahop.com'),
#  (2, 'Allez Hops! Cave à bièr', 'FRA', 'itsme@allezhops.com'),
#  (3, 'Wild Hops', 'ITA', 'myemail@wildhops.it'),
#  (4, 'Beer Paradise', 'ITA', 'beer@beerparadise.it')]

# %%
# %%sql
#
# SELECT * FROM supplier_to_product;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# INSERT INTO supplier_to_product
# VALUES
# (2,1),
# (3,1);
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# []

# %%
# %%sql
#
# SELECT * FROM supplier_to_product;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [(2, 1), (3, 1)]

# %% [markdown]
# Export the DB you have created into a .sql file, and store it for later use.
#
# 1. Connect to the "server" Docker container using bash
# 2. Dump the database using the `mysqldump` command
# ```bash
# $ mysqldump -u <USER> -p <DB NAME>  >  <FULL/PATH/TO/NEW/DB_DUMP.sql>
# ```
# 3. use the folder `/mapd-workspace/dbs` to store the file, as it's the one currently visible from both in- and outside the container

# %% [markdown]
# ## 04 Basic queries

# %% [markdown]
# The `SELECT` statement allows us to perform queries and retrieve data from a DB.
#
# We can perform queries on a single table in the DB, as well as perform complex queries that span multiple interconnected tables, with one-to-one, one-to-many, and many-to-many relationships across records.
#
# Any `SELECT` statement is composed of at least:
#
# ```sql
# SELECT <TABLE1.ATTRIBUTE1>, <TABLE2.ATTRIBUTE2>   --# the list of attributes to show
#                                                   --# the * wildcard symbol means ALL attributes
#
# FROM <TABLE1>, <TABLE2>                           --# the table, or list of tables
#                                                   --# from which to extract the attributes
#
# WHERE <CONDITIONS>                                --# (optional) condition statement
# ```
#
# The same structure applies to Python-based connectors:
#
# ```python
# db_cursor.execute("""
#     SELECT <TABLE1.ATTRIBUTE1>, <TABLE2.ATTRIBUTE2>
#     FROM <TABLE1>, <TABLE2>
#     WHERE <CONDITIONS>
# """)
# res_ = db_cursor.fetchall()
# for _ in res_:
#     print(_)
# ```
#
# As an alternative, `db_cursor.fetchone()` can be used to print out only one of possibly many records.

# %% [markdown]
# #### Get the email of all suppliers from Italy

# %%
# %%sql
#
# SELECT email
# FROM suppliers
# WHERE countryCode="ITA";
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [('myemail@wildhops.it',), ('beer@beerparadise.it',)]

# %% [markdown]
# #### Get all information for products with unit price greater than 4

# %%
# %%sql
#
# SELECT *
# FROM products
# WHERE unitPrice>4;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 3 rows affected.
# [(1, 'Founders Porter', 4.9, 12, 0),
#  (2, 'Punk IPA', 5.2, 45, 0),
#  (3, 'HB Dunkel', 4.5, 250, 0)]

# %% [markdown]
# #### Select all products with unit cost less than 5, and list them in descending order of units in stock

# %%
# %%sql
#
# SELECT *
# FROM products
# WHERE unitPrice<5
# ORDER BY unitsInStock DESC;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 3 rows affected.
# [(3, 'HB Dunkel', 4.5, 250, 0),
#  (5, 'Damm Complot', 3.7, 120, 0),
#  (1, 'Founders Porter', 4.9, 12, 0)]

# %% [markdown]
# **Group by** is a common statement that allows us to perform data aggregation.
#
# If you're familiar with `pandas`, this should not be new to you.
#
# Just remember:
# 1. No group by statement is possible without an aggregation function.
# 2. Group by operations can be quite computationally expensive. In the case of large databases, group by operations might require a long time to execute.

# %% [markdown]
# #### Plot the distribution of suppliers by country

# %%
# %%sql
#
# DESCRIBE suppliers;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [('supplierID', 'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('supplierName', 'varchar(30)', 'NO', '', '', ''),
#  ('countryCode', 'char(3)', 'NO', '', 'ITA', ''),
#  ('email', 'varchar(30)', 'NO', '', None, '')]

# %%
res_ = %sql SELECT COUNT(countryCode) AS count, countryCode FROM suppliers GROUP BY countryCode;

print (res_);

res_.bar();
# Out:
#  * mysql+mysqlconnector://root:***@db
# 3 rows affected.
# +-------+-------------+
# | count | countryCode |
# +-------+-------------+
# |   1   |     USA     |
# |   1   |     FRA     |
# |   2   |     ITA     |
# +-------+-------------+

# %% [markdown]
# The main strength of Relational DBs is the possibility of matching information from different tables through **Join** operations.
#
# A join, either performed explicitly or implicitly is:
#
# 1. Computationally expensive. In the case of large databases, join operations might require a long time to execute.
# 2. Very easy to be done wrong, thus resulting in non-meaningful results.
#
# Be sure of which attributes (most often keys) you are performing a join operation on.

# %% [markdown]
# #### Join the `supplier_to_product` table with the `suppliers` table

# %%
# %%sql
#
# SELECT *
# FROM suppliers, supplier_to_product
# WHERE supplier_to_product.supID = suppliers.supplierID;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [(1, 'A hop in the park', 'USA', 'anewemail@ahop.com', 2, 1),
#  (1, 'A hop in the park', 'USA', 'anewemail@ahop.com', 3, 1)]

# %%
# %%sql
#
# SELECT *
# FROM suppliers
# INNER JOIN supplier_to_product ON supplier_to_product.supID = suppliers.supplierID;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [(1, 'A hop in the park', 'USA', 'anewemail@ahop.com', 2, 1),
#  (1, 'A hop in the park', 'USA', 'anewemail@ahop.com', 3, 1)]

# %%
# %%sql
#
# SELECT *
# FROM suppliers
# LEFT JOIN supplier_to_product ON supplier_to_product.supID = suppliers.supplierID;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [(1, 'A hop in the park', 'USA', 'anewemail@ahop.com', 2, 1),
#  (1, 'A hop in the park', 'USA', 'anewemail@ahop.com', 3, 1),
#  (2, 'Allez Hops! Cave à bièr', 'FRA', 'itsme@allezhops.com', None, None),
#  (3, 'Wild Hops', 'ITA', 'myemail@wildhops.it', None, None),
#  (4, 'Beer Paradise', 'ITA', 'beer@beerparadise.it', None, None)]

# %%
# %%sql
#
# SELECT *
# FROM suppliers
# RIGHT JOIN supplier_to_product ON supplier_to_product.supID = suppliers.supplierID;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [(1, 'A hop in the park', 'USA', 'anewemail@ahop.com', 2, 1),
#  (1, 'A hop in the park', 'USA', 'anewemail@ahop.com', 3, 1)]

# %% [markdown]
# We can concatenate multiple join operations to extract higher-level information out of the connections stored in the database.
#
# #### Add the corresponding product names to the previous join

# %%
# %%sql
#
# SELECT *
# FROM suppliers
# INNER JOIN supplier_to_product ON supplier_to_product.supID = suppliers.supplierID
# INNER JOIN products ON supplier_to_product.prodID = products.productID;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [(1, 'A hop in the park', 'USA', 'anewemail@ahop.com', 2, 1, 2, 'Punk IPA', 5.2, 45, 0),
#  (1, 'A hop in the park', 'USA', 'anewemail@ahop.com', 3, 1, 3, 'HB Dunkel', 4.5, 250, 0)]

# %% [markdown]
# The conjunction of `SELECT`, `GROUP BY`, and `JOIN` statements will allow us to extract non-trivial information out of any Relational database.
#
# #### Add the following records to the `supplier_to_product` table, and perform the following queries:
#
# | supplier | products provided |
# | --- | --- |
# | "Wild Hops" | "Founders Porter", "Punk IPA", "HB Dunkel", "Damm Complot" |
# | "Beer Paradise" | "Punk IPA", "Damm Complot" |
# | "Allez Hops! Cave à bièr" | "Founders Porter", "HB Dunkel" |
#
# 1. show all suppliers of "Damm Complot"
# 2. retrieve the email address of all possible suppliers of "Punk IPA"
# 3. list the unit price of all products supplied by Italian firms, listed in descending order (of unit price)

# %%
sql_ = "INSERT INTO supplier_to_product (prodID, supID) VALUES (%s, %s)"
val_ = [
    # supplier Allez Hops
    (1, 2),
    (3, 2),

    # supplier Wild Hops
    (1, 3),
    (2, 3),
    (3, 3),
    (5, 3),

    # supplier Beer Paradise
    (2, 4),
    (5, 4),
]


dbc.executemany(sql_, val_)
db.commit()
     
dbc.execute("SELECT * FROM supplier_to_product"); 
for _ in dbc:
     print(_)
# Out:
# (2, 1)
# (3, 1)
# (1, 2)
# (3, 2)
# (1, 3)
# (2, 3)
# (3, 3)
# (5, 3)
# (2, 4)
# (5, 4)

# %%
# %%sql
#
# SELECT suppliers.supplierName
# FROM supplier_to_product
# INNER JOIN suppliers ON supplier_to_product.supID = suppliers.supplierID
# INNER JOIN products ON supplier_to_product.prodID = products.productID
# WHERE products.productName = "Punk IPA";
# Out:
#  * mysql+mysqlconnector://root:***@db
# 3 rows affected.
# [('A hop in the park',), ('Wild Hops',), ('Beer Paradise',)]

# %%
# %%sql
#
# SELECT suppliers.email
# FROM supplier_to_product
# INNER JOIN suppliers ON supplier_to_product.supID = suppliers.supplierID
# INNER JOIN products ON supplier_to_product.prodID = products.productID
# WHERE products.productName = "Punk IPA";
# Out:
#  * mysql+mysqlconnector://root:***@db
# 3 rows affected.
# [('anewemail@ahop.com',), ('myemail@wildhops.it',), ('beer@beerparadise.it',)]

# %%
# %%sql
#
# SELECT DISTINCT products.unitPrice, products.productName
# FROM supplier_to_product
# INNER JOIN suppliers ON supplier_to_product.supID = suppliers.supplierID
# INNER JOIN products ON supplier_to_product.prodID = products.productID
# WHERE suppliers.countryCode = "ITA"
# ORDER BY unitPrice DESC;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [(5.2, 'Punk IPA'),
#  (4.9, 'Founders Porter'),
#  (4.5, 'HB Dunkel'),
#  (3.7, 'Damm Complot')]

# %% [markdown]
# ## 05 Queries on well-formed DBs
#
# In MySQL, we can load entire databases from external files.
#
# The files will contain the full database structure (tables and constraints) and will populate all tables with all records.
#
# To load a database into the MySQL server from the interactive Docker shell, we can simply do the following:
#
# 1. Create a new database named `world`.
# 2. Import the content of the file `/mapd-workspace/dbs/world.sql` into the newly created database via:
#
# ```bash
# $ mysql -u root -p world < /mapd-workspace/dbs/world.sql
# ```
#
# **NB**: The `/mapd-workspace` directory has been defined as a Docker Volume and is a shared location with your computer.

# %% [markdown]
# #### Using the `world` DB, perform queries to answer the following questions.
#
# Additional references can be found here https://dev.mysql.com/doc/world-setup/en/
#
#
# Use a **single query** to answer the questions:
#
# 1. Which country has the largest population?
# 2. Get the total number of cities in Canada.
# 3. Select the country with the most cities.
# 4. List all the languages spoken in the Southeast Asia region.
# 5. Identify the 5 most spoken languages by number of countries.
# 6. What is the total population of the cities in the Caribbean region?
# 7. What Countries have a City named "Kingston"?
# 8. Plot the population density by country, limiting to the 25 with the least density.
# 9. Plot the GNP (Gross Nation Product) of all countries that become independent between 1850 and 1910, limiting to the 10 with the highest GNP.
# 10. Create a scatter plot of the life expectancy vs the GNP of all countries that have Spanish as their Official language.
#
#
# ##### Suggestions:
# - Start by inspecting the database tables' structure
# - When in doubt, check the table content by selecting only a few lines (use `LIMIT` to avoid returning all records)
# - Before finalizing the query, you can always perform "intermediate" queries to check if complex operations (e.g. `GROUP BY` and `JOIN`) are stated correctly

# %%
# %%sql
#
# USE world;
#
# SHOW TABLES;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# 3 rows affected.
# [('city',), ('country',), ('countrylanguage',)]

# %%
# %%sql
#
# DESCRIBE city
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('ID', 'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('Name', 'char(35)', 'NO', '', '', ''),
#  ('CountryCode', 'char(3)', 'NO', 'MUL', '', ''),
#  ('District', 'char(20)', 'NO', '', '', ''),
#  ('Population', 'int', 'NO', '', '0', '')]

# %%
# %%sql
#
# SELECT *
# FROM city
# LIMIT 5
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [(1, 'Kabul', 'AFG', 'Kabol', 1780000),
#  (2, 'Qandahar', 'AFG', 'Qandahar', 237500),
#  (3, 'Herat', 'AFG', 'Herat', 186800),
#  (4, 'Mazar-e-Sharif', 'AFG', 'Balkh', 127800),
#  (5, 'Amsterdam', 'NLD', 'Noord-Holland', 731200)]

# %%
# %%sql
#
# DESCRIBE country
# Out:
#  * mysql+mysqlconnector://root:***@db
# 15 rows affected.
# [('Code', 'char(3)', 'NO', 'PRI', '', ''),
#  ('Name', 'char(52)', 'NO', '', '', ''),
#  ('Continent', "enum('Asia','Europe','North America','Africa','Oceania','Antarctica','South America')", 'NO', '', 'Asia', ''),
#  ('Region', 'char(26)', 'NO', '', '', ''),
#  ('SurfaceArea', 'decimal(10,2)', 'NO', '', '0.00', ''),
#  ('IndepYear', 'smallint', 'YES', '', None, ''),
#  ('Population', 'int', 'NO', '', '0', ''),
#  ('LifeExpectancy', 'decimal(3,1)', 'YES', '', None, ''),
#  ('GNP', 'decimal(10,2)', 'YES', '', None, ''),
#  ('GNPOld', 'decimal(10,2)', 'YES', '', None, ''),
#  ('LocalName', 'char(45)', 'NO', '', '', ''),
#  ('GovernmentForm', 'char(45)', 'NO', '', '', ''),
#  ('HeadOfState', 'char(60)', 'YES', '', None, ''),
#  ('Capital', 'int', 'YES', '', None, ''),
#  ('Code2', 'char(2)', 'NO', '', '', '')]

# %% [markdown]
# #### 1 - Which country has the largest population?

# %%
# %%sql
#
# # SELECT   ,
# # FROM
# # ORDER BY     DESC
# # LIMIT 1;

# %% [markdown]
# #### 2 - Get the total number of cities in Canada.

# %%
# %%sql
#
# SELECT Name, Population
# FROM country
# ORDER BY Population DESC
# LIMIT 1;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [('China', 1277558000)]

# %%
# %%timeit -n 10
# %%sql 

SELECT COUNT(Name) AS CitiesInCanada
FROM city
WHERE CountryCode = "CAN";
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# 6.71 ms ± 316 μs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit -n 10
# %%sql 

SELECT COUNT(*) AS CitiesInCanada
FROM city
WHERE CountryCode = "CAN";
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# 6.38 ms ± 523 μs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit -n 10
# %%sql 

SELECT COUNT(1) AS CitiesInCanada
FROM city
WHERE CountryCode = "CAN";
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# 6.52 ms ± 477 μs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# #### 3 - Select the country with the most cities.

# %%
# %%sql
#
# SELECT CountryCode, COUNT(1) AS nCities
# FROM city
# GROUP BY CountryCode
# ORDER BY nCities DESC
# LIMIT 1;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [('CHN', 363)]

# %% [markdown]
# #### 4 - List all the languages spoken in the Southeast Asia region.

# %% [markdown]
# First, one can for instance check the list of countries in all the "...Asia" regions available in the `country` table

# %%
# %%sql
#
# SELECT Region, COUNT(1)
# FROM country
# WHERE Region LIKE "%Asia"
# GROUP BY Region;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 3 rows affected.
# [('Southern and Central Asia', 14),
#  ('Southeast Asia', 11),
#  ('Eastern Asia', 8)]

# %% [markdown]
# Then, we can select exactly the `Southeast Asia` ones, and perform a inner join with the `countrylanguage` table.
# Here the inner join is implicit.

# %%
# %%sql
#
# SELECT DISTINCT countrylanguage.Language
# FROM country, countrylanguage
# WHERE country.Region = "Southeast Asia"
# AND country.Code = countrylanguage.countryCode
# ORDER BY countrylanguage.Language ASC;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 47 rows affected.
# [('Bali',),
#  ('Banja',),
#  ('Batakki',),
#  ('Bicol',),
#  ('Bugi',),
#  ('Burmese',),
#  ('Cebuano',),
#  ('Chin',),
#  ('Chinese',),
#  ('Dusun',),
#  ('English',),
#  ('Hiligaynon',),
#  ('Iban',),
#  ('Ilocano',),
#  ('Javanese',),
#  ('Kachin',),
#  ('Karen',),
#  ('Kayah',),
#  ('Khmer',),
#  ('Kuy',),
#  ('Lao',),
#  ('Lao-Soung',),
#  ('Madura',),
#  ('Maguindanao',),
#  ('Malay',),
#  ('Malay-English',),
#  ('Man',),
#  ('Maranao',),
#  ('Miao',),
#  ('Minangkabau',),
#  ('Mon',),
#  ('Mon-khmer',),
#  ('Muong',),
#  ('Nung',),
#  ('Pampango',),
#  ('Pangasinan',),
#  ('Pilipino',),
#  ('Portuguese',),
#  ('Rakhine',),
#  ('Shan',),
#  ('Sunda',),
#  ('Tamil',),
#  ('Thai',),
#  ('Tho',),
#  ('Tšam',),
#  ('Vietnamese',),
#  ('Waray-waray',)]

# %% [markdown]
# Here is instead explicit

# %%
# %%sql
#
# SELECT DISTINCT countrylanguage.Language
# FROM country
# INNER JOIN countrylanguage ON country.Code = countrylanguage.countryCode
# WHERE country.Region = "Southeast Asia"
# ORDER BY countrylanguage.Language ASC;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 47 rows affected.
# [('Bali',),
#  ('Banja',),
#  ('Batakki',),
#  ('Bicol',),
#  ('Bugi',),
#  ('Burmese',),
#  ('Cebuano',),
#  ('Chin',),
#  ('Chinese',),
#  ('Dusun',),
#  ('English',),
#  ('Hiligaynon',),
#  ('Iban',),
#  ('Ilocano',),
#  ('Javanese',),
#  ('Kachin',),
#  ('Karen',),
#  ('Kayah',),
#  ('Khmer',),
#  ('Kuy',),
#  ('Lao',),
#  ('Lao-Soung',),
#  ('Madura',),
#  ('Maguindanao',),
#  ('Malay',),
#  ('Malay-English',),
#  ('Man',),
#  ('Maranao',),
#  ('Miao',),
#  ('Minangkabau',),
#  ('Mon',),
#  ('Mon-khmer',),
#  ('Muong',),
#  ('Nung',),
#  ('Pampango',),
#  ('Pangasinan',),
#  ('Pilipino',),
#  ('Portuguese',),
#  ('Rakhine',),
#  ('Shan',),
#  ('Sunda',),
#  ('Tamil',),
#  ('Thai',),
#  ('Tho',),
#  ('Tšam',),
#  ('Vietnamese',),
#  ('Waray-waray',)]

# %% [markdown]
# #### 5 - Identify the 5 most spoken languages by number of countries.

# %%
# %%sql
#
# SELECT Language, COUNT(Language) AS count
# FROM countrylanguage
# GROUP BY Language
# ORDER BY COUNT(Language) DESC
# LIMIT 5;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('English', 60),
#  ('Arabic', 33),
#  ('Spanish', 28),
#  ('French', 25),
#  ('German', 19)]

# %% [markdown]
# #### 6 - What is the total population of the cities in the Caribbean region?

# %%
# %%sql
#
# SELECT SUM(city.Population)
# FROM city
# LEFT JOIN country ON city.countryCode = country.Code
# WHERE country.Region = 'Caribbean';
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [(Decimal('11067550'),)]

# %% [markdown]
# In this case the same result could have been achieved with `LEFT`/`RIGHT` and `INNER JOIN`

# %%
# %%sql
#
# SELECT SUM(city.Population)
# FROM city
# INNER JOIN country ON city.countryCode = country.Code
# WHERE country.Region = 'Caribbean';
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [(Decimal('11067550'),)]

# %% [markdown]
# #### 7 - What Countries have a City named "Kingston"?

# %%
# %%sql
#
# SELECT country.Name, country.Region
# FROM country
# RIGHT JOIN city ON city.countryCode = country.Code
# WHERE city.Name = 'Kingston';
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [('Jamaica', 'Caribbean'), ('Norfolk Island', 'Australia and New Zealand')]

# %% [markdown]
# Also in this case, the same result could have been achieved with `LEFT`/`RIGHT` and `INNER JOIN`

# %%
# %%sql
#
# SELECT country.Name, country.Region
# FROM country
# INNER JOIN city ON city.countryCode = country.Code
# WHERE city.Name = 'Kingston';
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [('Jamaica', 'Caribbean'), ('Norfolk Island', 'Australia and New Zealand')]

# %% [markdown]
# #### 8 - Plot the population density by country, limiting to the 25 with the least density.

# %% [markdown]
# The population density is the total `Population` of a country divided by the `SurfaceArea`.
# We can compute this quantity on the fly during a `SELECT` statement and rename it with an `ALIAS` for convenience.

# %%
# %%sql
#
# SELECT Name, Population/SurfaceArea AS PopDensity
# FROM country
# LIMIT 2;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [('Aruba', Decimal('533.6788')), ('Afghanistan', Decimal('34.8418'))]

# %% [markdown]
# We can then redirect the output of the SQL statement, including the ordering and the limit, into a Python variable and then plot it directly with the `.bar()` method
#
# For more info on the MySQL Notebook magic check the link [here](https://github.com/catherinedevlin/ipython-sql#graphing), and thank the developers for their hard work.

# %%
res_ = %sql SELECT Name, Population/SurfaceArea AS PopDensity FROM country ORDER BY PopDensity ASC LIMIT 25;

print(res_)

plt.figure(figsize=(16,3))
res_.bar();
plt.xticks(rotation='vertical');
# Out:
#  * mysql+mysqlconnector://root:***@db
# 25 rows affected.
# +----------------------------------------------+------------+
# |                     Name                     | PopDensity |
# +----------------------------------------------+------------+
# |     United States Minor Outlying Islands     |   0.0000   |
# |        British Indian Ocean Territory        |   0.0000   |
# |      Heard Island and McDonald Islands       |   0.0000   |
# | South Georgia and the South Sandwich Islands |   0.0000   |
# |                Bouvet Island                 |   0.0000   |
# |         French Southern territories          |   0.0000   |
# |                  Antarctica                  |   0.0000   |
# |                  Greenland                   |   0.0259   |
# |            Svalbard and Jan Mayen            |   0.0513   |
# |               Falkland Islands               |   0.1643   |
# |                   Pitcairn                   |   1.0204   |
# |                Western Sahara                |   1.1015   |
# |                   Mongolia                   |   1.6993   |
# |                French Guiana                 |   2.0111   |
# |                   Namibia                    |   2.0939   |
# |                  Australia                   |   2.4397   |
# |                   Suriname                   |   2.5541   |
# |                  Mauritania                  |   2.6036   |
# |                   Iceland                    |   2.7087   |
# |                   Botswana                   |   2.7882   |
# |                    Canada                    |   3.1239   |
# |            Libyan Arab Jamahiriya            |   3.1855   |
# |                    Guyana                    |   4.0052   |
# |                    Gabon                     |   4.5803   |
# |           Central African Republic           |   5.8027   |
# +----------------------------------------------+------------+

# %% [markdown]
# #### 9 - Plot the GNP (Gross Nation Product) of all countries that become independent between 1850 and 1910, limiting to the 10 with the highest GNP

# %% [markdown]
# We can use `BETWEEN a AND b` to select only those entries between two extremes;

# %%
# %%sql
#
# SELECT Name, GNP
# FROM country
# WHERE IndepYear BETWEEN 1850 AND 1910
# LIMIT 2;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [('Australia', Decimal('351182.00')), ('Bulgaria', Decimal('12178.00'))]

# %% [markdown]
# Then, once again, combine all (including the proper ordering) in a python variable, and plot the results

# %%
res_ = %sql SELECT Name, GNP FROM country WHERE IndepYear BETWEEN 1850 AND 1910 ORDER BY GNP DESC;

print(res_)

plt.figure(figsize=(16,3))
res_.bar();
plt.xticks(rotation='vertical');
# Out:
#  * mysql+mysqlconnector://root:***@db
# 14 rows affected.
# +--------------+------------+
# |     Name     |    GNP     |
# +--------------+------------+
# |    Italy     | 1161755.00 |
# |    Canada    | 598862.00  |
# |  Australia   | 351182.00  |
# |     Iran     | 195746.00  |
# |    Norway    | 145895.00  |
# | South Africa | 116729.00  |
# | New Zealand  |  54669.00  |
# |   Romania    |  38158.00  |
# |     Cuba     |  17843.00  |
# |  Luxembourg  |  16321.00  |
# |   Bulgaria   |  12178.00  |
# |    Panama    |  9131.00   |
# |    Monaco    |   776.00   |
# |    Bhutan    |   372.00   |
# +--------------+------------+

# %% [markdown]
# #### 10 - Create a scatter plot of the life expectancy vs the GNP of all countries that have Spanish as their Official language

# %%
res_ = %sql SELECT LifeExpectancy, GNP, country.Name \
FROM country \
RIGHT JOIN countrylanguage ON countrylanguage.countryCode = country.Code \
WHERE Language = 'Spanish' \
AND IsOfficial = 1;

print(res_)

plt.figure(figsize=(8,6));
for _ in res_:
    plt.scatter(_[0],_[1],s=50);
    plt.annotate(_[2], (float(_[0])*1.002,float(_[1])*1.002));
plt.ylabel('GNP');
plt.xlabel('LifeExpectancy');
plt.yscale('log');
# Out:
#  * mysql+mysqlconnector://root:***@db
# 20 rows affected.
# +----------------+-----------+--------------------+
# | LifeExpectancy |    GNP    |        Name        |
# +----------------+-----------+--------------------+
# |      75.1      | 340238.00 |     Argentina      |
# |      63.7      |  8571.00  |      Bolivia       |
# |      75.7      |  72949.00 |       Chile        |
# |      70.3      | 102896.00 |      Colombia      |
# |      75.8      |  10226.00 |     Costa Rica     |
# |      76.2      |  17843.00 |        Cuba        |
# |      73.2      |  15846.00 | Dominican Republic |
# |      71.1      |  19770.00 |      Ecuador       |
# |      78.8      | 553233.00 |       Spain        |
# |      66.2      |  19008.00 |     Guatemala      |
# |      69.9      |  5333.00  |      Honduras      |
# |      71.5      | 414972.00 |       Mexico       |
# |      68.7      |  1988.00  |     Nicaragua      |
# |      75.5      |  9131.00  |       Panama       |
# |      70.0      |  64140.00 |        Peru        |
# |      75.6      |  34100.00 |    Puerto Rico     |
# |      73.7      |  8444.00  |      Paraguay      |
# |      69.7      |  11863.00 |    El Salvador     |
# |      75.2      |  20831.00 |      Uruguay       |
# |      73.1      |  95023.00 |     Venezuela      |
# +----------------+-----------+--------------------+

# %% [markdown]
# ## 06 More on queries

# %% [markdown]
# Let's import a well-structured database, with several tables and relationships, to be used as a sandbox for further exercises on queries.
#
# The database is freely available and is taken from the IMDb (Internet Movie Database) website (https://www.imdb.com/interfaces/), although severely slimmed down.
#
# This database contains several tables with information about movies, TV shows, people involved in the entertainment industry, and more, spanning from the 1890s to recent years.
#
# To simplify the execution of queries, we will work with a slimmed-down version of the entire database, with still plenty of records for us to extract interesting information.
#
# To start working with the IMDb database, we need to import it into our environment. The database `.sql` file should be downloaded from the link on Moodle and copied into the `/mysql/dbs` folder of the GitHub repository so that it will be found in the mounted volume at the location: `/mapd-workspace/dbs/IMDb_pruned.sql`.

# %% [markdown]
# 1. Create a new DB named `IMDb`
# 2. Import the content of the file `/mapd-workspace/dbs/IMDb_pruned.sql` into the newly created DB
# (this might take a minute or two...)

# %% [markdown]
# ### Check which tables are available

# %%
# %%sql
#
# USE IMDb;
#
# SHOW TABLES;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# 7 rows affected.
# [('Directors',),
#  ('Episode_belongs_to',),
#  ('Had_role',),
#  ('Names_',),
#  ('Title_genres',),
#  ('Title_ratings',),
#  ('Titles',)]

# %% [markdown]
# ### Describe the content of table `Names_`

# %%
# %%sql
#
# DESCRIBE Names_;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [('name_id', 'varchar(255)', 'NO', '', None, ''),
#  ('name_', 'varchar(255)', 'NO', '', None, ''),
#  ('birth_year', 'smallint', 'YES', '', None, ''),
#  ('death_year', 'smallint', 'YES', '', None, '')]

# %% [markdown]
# ### Study the distribution of the year of birth of all people included in the database
#
# 1. Start by limiting the query to 1000 entries
#     1. Draw a histogram of the year of birth
#     1. Draw a second histogram with the year of birth of the 1000 youngest people in the list

# %%
# 1.A

db = mysql.connector.connect(
  user="root",
  password="root_pwd",
  host="db"
)

dbc = db.cursor()

dbc.execute("USE IMDb")

import itertools
dbc.execute("SELECT birth_year FROM Names_ LIMIT 1000")
myresult = dbc.fetchall()  
# plt.hist([x[0] for x in myresult])       # list-comprehension of 0-th elements in tuple
# plt.hist(list(zip(*myresult))[0])        # un-zip the tuple in a list and take the 0-the element
plt.hist(list(itertools.chain(*myresult))); # un-wrap the tuple in a list
plt.xlabel('year');
plt.ylabel('count');

# The same could be done by selecting *.
# In this case though, the returned value 
# retains the table schema
# 
# dbc.execute("SELECT * FROM Names_ LIMIT 1000")
# myresult = dbc.fetchall()    
# plt.hist([x[2] for x in myresult])
# plt.hist(list(zip(*myresult))[2])

# %%
# 1.B

dbc.execute("SELECT birth_year FROM Names_ ORDER BY birth_year DESC LIMIT 1000 ")
myresult = dbc.fetchall()  
plt.hist(list(itertools.chain(*myresult)));
plt.xlabel('year');
plt.ylabel('count');

# %% [markdown]
# 2. Extend the query to all records in the table
#     1. Check for outliers (inspect min and max)
#     2. If any outlier is found, limit the query to a reasonable range (say... at least people born after 1850)
#     3. Draw a new histogram with the year of birth
#     4. Compute the mean and standard deviation of the year of birth

# %%
# %%sql
#
# # 2.A
#
# USE IMDb;
#
# SELECT MIN(birth_year),MAX(birth_year) FROM Names_;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# 1 rows affected.
# [(13, 2021)]

# %%
# %%sql
#
# SELECT COUNT(*),MIN(birth_year),MAX(birth_year)
# FROM Names_
# WHERE (birth_year < 1850);
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [(2, 13, 1088)]

# %%
# %%sql
#
# # 2.B
#
# SELECT *
# FROM Names_
# WHERE (birth_year < 1850);
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [('nm1620433', 'Karen Abercrombie', 13, None),
#  ('nm8066610', 'Sophie Oliver', 1088, None)]

# %%
# 2.C

dbc.execute("SELECT birth_year\
             FROM Names_\
             WHERE (birth_year > 1850)")
myresult = dbc.fetchall()  
plt.hist(list(itertools.chain(*myresult)),
        bins=50);

# %%
# 2.D

_ = %sql SELECT AVG(birth_year) AS mean, STD(birth_year) AS std FROM Names_ WHERE (birth_year > 1850)

print (_)
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# +-----------+-------------------+
# |    mean   |        std        |
# +-----------+-------------------+
# | 1965.4513 | 19.99205313179966 |
# +-----------+-------------------+

# %% [markdown]
# ### Movie stats
#
# 1. Plot the number of titles available in the database for each year over the past 25 years.
# 2. List the names of all actors who have portrayed the character Spider-Man in movies, along with the corresponding movie titles.
# 3. List and count the top 10 people who have appeared the most in movies directed by Wes Anderson.

# %% [markdown]
# #### 1 - Plot the number of titles available in the database for each year over the past 25 years.

# %%
# %%sql
#
# DESCRIBE Titles;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('title_id', 'varchar(255)', 'NO', '', None, ''),
#  ('title_type', 'varchar(50)', 'YES', '', None, ''),
#  ('primary_title', 'text', 'YES', '', None, ''),
#  ('start_year', 'int', 'YES', '', None, ''),
#  ('runtime_minutes', 'int', 'YES', '', None, '')]

# %%
# %%sql
#
# SELECT start_year AS year, COUNT(*) AS count
# FROM Titles
# WHERE (start_year >= 1999)
# GROUP BY start_year
# ORDER BY start_year DESC;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 29 rows affected.
# [(2027, 1),
#  (2026, 3),
#  (2025, 4),
#  (2024, 14),
#  (2023, 161),
#  (2022, 6211),
#  (2021, 51422),
#  (2020, 56755),
#  (2019, 61580),
#  (2018, 66211),
#  (2017, 65984),
#  (2016, 61554),
#  (2015, 55864),
#  (2014, 50654),
#  (2013, 46740),
#  (2012, 43170),
#  (2011, 39155),
#  (2010, 35706),
#  (2009, 34450),
#  (2008, 30564),
#  (2007, 27860),
#  (2006, 24898),
#  (2005, 22746),
#  (2004, 19711),
#  (2003, 18189),
#  (2002, 16937),
#  (2001, 16598),
#  (2000, 15677),
#  (1999, 16643)]

# %%
res_ = %sql SELECT start_year AS year, COUNT(*) AS count FROM Titles WHERE (start_year >= 1997) GROUP BY start_year ORDER BY start_year DESC;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 31 rows affected.

# %%
# the result of a query is also a special type that can be casted into a variety of formats
print(type(res_))

print('DICTIONARY\n\n {} \n\n'.format(res_.dict()))
print('CSV\n\n {} \n\n'.format(res_.csv()))
print('PANDAS DATAFRAME\n\n')
res_.DataFrame()
# Out:
# <class 'sql.run.ResultSet'>
# DICTIONARY
#
#  {'year': (2027, 2026, 2025, 2024, 2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000, 1999, 1998, 1997), 'count': (1, 3, 4, 14, 161, 6211, 51422, 56755, 61580, 66211, 65984, 61554, 55864, 50654, 46740, 43170, 39155, 35706, 34450, 30564, 27860, 24898, 22746, 19711, 18189, 16937, 16598, 15677, 16643, 15749, 15206)}
#
#
# CSV
#
#  year,count
# 2027,1
# 2026,3
# 2025,4
# 2024,14
# 2023,161
# 2022,6211
# 2021,51422
# 2020,56755
# 2019,61580
# 2018,66211
# 2017,65984
# 2016,61554
# 2015,55864
# 2014,50654
# 2013,46740
# 2012,43170
# 2011,39155
# 2010,35706
# 2009,34450
# 2008,30564
# 2007,27860
# 2006,24898
# 2005,22746
# 2004,19711
# 2003,18189
# 2002,16937
# 2001,16598
# 2000,15677
# 1999,16643
# 1998,15749
# 1997,15206
#
#
#
# PANDAS DATAFRAME
#     year  count
# 0   2027      1
# 1   2026      3
# 2   2025      4
# 3   2024     14
# 4   2023    161
# 5   2022   6211
# 6   2021  51422
# 7   2020  56755
# 8   2019  61580
# 9   2018  66211
# 10  2017  65984
# 11  2016  61554
# 12  2015  55864
# 13  2014  50654
# 14  2013  46740
# 15  2012  43170
# 16  2011  39155
# 17  2010  35706
# 18  2009  34450
# 19  2008  30564
# 20  2007  27860
# 21  2006  24898
# 22  2005  22746
# 23  2004  19711
# 24  2003  18189
# 25  2002  16937
# 26  2001  16598
# 27  2000  15677
# 28  1999  16643
# 29  1998  15749
# 30  1997  15206

# %%
# we can thus use the dict to plot the results
plt.plot('year',
         'count',
         data = res_.dict());
plt.xlabel('years')
plt.ylabel('counts')
# Out:
# Text(0, 0.5, 'counts')

# %%
# however, the sql result class also include a number of built-in features, such as automated plotting
res_.plot();

# %% [markdown]
# #### 2 - List the names of all actors who have portrayed the character Spider-Man in movies, along with the corresponding movie titles.

# %%
# %%sql
#
# DESCRIBE Had_role;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 3 rows affected.
# [('title_id', 'varchar(255)', 'NO', '', None, ''),
#  ('name_id', 'varchar(255)', 'NO', '', None, ''),
#  ('role_', 'text', 'NO', '', None, '')]

# %%
# %%sql
#
# DESCRIBE Names_;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [('name_id', 'varchar(255)', 'NO', '', None, ''),
#  ('name_', 'varchar(255)', 'NO', '', None, ''),
#  ('birth_year', 'smallint', 'YES', '', None, ''),
#  ('death_year', 'smallint', 'YES', '', None, '')]

# %%
# %%sql
#
# DESCRIBE Titles;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('title_id', 'varchar(255)', 'NO', '', None, ''),
#  ('title_type', 'varchar(50)', 'YES', '', None, ''),
#  ('primary_title', 'text', 'YES', '', None, ''),
#  ('start_year', 'int', 'YES', '', None, ''),
#  ('runtime_minutes', 'int', 'YES', '', None, '')]

# %%
# %%sql
#
# # Using an implicit join operation
#
# SELECT DISTINCT Names_.name_
# FROM Names_
# WHERE (
#     Names_.name_id IN (
#         SELECT Had_role.name_id
#         FROM Had_role
#         WHERE (Had_role.role_ LIKE "Spider-Man")
#     )
# )
# ORDER BY Names_.name_ ;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 20 rows affected.
# [('Aaron Schoenke',),
#  ('Andrew Garfield',),
#  ('Andy Richter',),
#  ('Christopher Daniel Barnes',),
#  ('Cole Howard',),
#  ('Doug Walker',),
#  ('Drake Bell',),
#  ('Forrest Whaley',),
#  ('Ian Hecox',),
#  ('JP Karliak',),
#  ('Josh Keaton',),
#  ('Mikey Day',),
#  ('Neil Patrick Harris',),
#  ('Rino Romano',),
#  ('Robbie Daymond',),
#  ('Sean Chiplock',),
#  ('Shane Dawson',),
#  ('Stan Lee',),
#  ('Tobey Maguire',),
#  ('Tom Holland',)]

# %%
# %%sql
#
# # Moving to a (always preferrable) explicit join operation
#
# SELECT DISTINCT Names_.name_
# FROM Names_
# JOIN Had_role ON Names_.name_id = Had_role.name_id
# WHERE Had_role.role_ LIKE "Spider-Man"
# ORDER BY Names_.name_ ;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 20 rows affected.
# [('Aaron Schoenke',),
#  ('Andrew Garfield',),
#  ('Andy Richter',),
#  ('Christopher Daniel Barnes',),
#  ('Cole Howard',),
#  ('Doug Walker',),
#  ('Drake Bell',),
#  ('Forrest Whaley',),
#  ('Ian Hecox',),
#  ('JP Karliak',),
#  ('Josh Keaton',),
#  ('Mikey Day',),
#  ('Neil Patrick Harris',),
#  ('Rino Romano',),
#  ('Robbie Daymond',),
#  ('Sean Chiplock',),
#  ('Shane Dawson',),
#  ('Stan Lee',),
#  ('Tobey Maguire',),
#  ('Tom Holland',)]

# %%
# %%sql
#
# # SELECT DISTINCT Titles.primary_title
# # FROM Titles
# # WHERE (
# #     Titles.title_id IN (
# #         SELECT Had_role.title_id
# #         FROM Had_role
# #         WHERE (Had_role.role_ LIKE "Spider-Man")
# #     )
# # );
#
# SELECT DISTINCT Titles.primary_title
# FROM Titles
# INNER JOIN Had_role ON Titles.title_id = Had_role.title_id
# WHERE Had_role.role_ LIKE 'Spider-Man';
# Out:
#  * mysql+mysqlconnector://root:***@db
# 348 rows affected.
# [('Spider-Man: The Animated Series',),
#  ('Spider-Man',),
#  ('Spider-Man Unlimited',),
#  ('Spider-Man 2',),
#  ('Spider-Man 3',),
#  ('Cry Vulture',),
#  ('Deadly Choices',),
#  ('Destiny Unleashed',),
#  ('Ill-Met by Moonlight',),
#  ('Matters of the Heart',),
#  ('One Is the Loneliest Number',),
#  ('Sins of the Fathers',),
#  ('Steel Cold Heart',),
#  ('Sustenance',),
#  ('Where Evil Nests',),
#  ('Worlds Apart: Part 1',),
#  ('Worlds Apart: Part 2',),
#  ('Day of the Chameleon',),
#  ('Doctor Octopus: Armed and Dangerous',),
#  ('Kraven the Hunter',),
#  ('Neogenic Nightmare Chapter 10: The Immortal Vampire',),
#  ('Neogenic Nightmare Chapter 11: Tablet of Time',),
#  ('Neogenic Nightmare Chapter 12: Ravages of Time',),
#  ('Neogenic Nightmare Chapter 13: Shriek of the Vulture',),
#  ('Neogenic Nightmare Chapter 14: The Final Nightmare',),
#  ('Neogenic Nightmare Chapter 1: The Insidious Six',),
#  ('Neogenic Nightmare Chapter 2: Battle of the Insidious Six',),
#  ('Neogenic Nightmare Chapter 3: Hydro-Man',),
#  ('Neogenic Nightmare Chapter 4: The Mutant Agenda',),
#  ('Neogenic Nightmare Chapter 5: Mutants Revenge',),
#  ('Neogenic Nightmare Chapter 6: Morbius',),
#  ('Neogenic Nightmare Chapter 7: Enter the Punisher',),
#  ('Neogenic Nightmare Chapter 8: Duel of the Hunters',),
#  ('Neogenic Nightmare Chapter 9: Blade the Vampire Hunter',),
#  ('Night of the Lizard',),
#  ('Partners in Danger Chapter 10: Lizard King',),
#  ('Partners in Danger Chapter 11: The Prowler',),
#  ('Partners in Danger Chapter 1: Guilty',),
#  ('Partners in Danger Chapter 2: The Cat',),
#  ('Partners in Danger Chapter 3: The Black Cat',),
#  ('Partners in Danger Chapter 4: Return of Kraven',),
#  ('Partners in Danger Chapter 5: Partners',),
#  ('Partners in Danger Chapter 6: The Awakening',),
#  ('Partners in Danger Chapter 7: The Vampire Queen',),
#  ('Partners in Danger Chapter 8: The Return of the Green Goblin',),
#  ('Partners in Danger Chapter 9: The Haunting of Mary Jane',),
#  ('Secret Wars, Chapter 1: Arrival',),
#  ('Secret Wars, Chapter 2: The Gauntlet of the Red Skull',),
#  ('Secret Wars, Chapter 3: Doom',),
#  ('Sins of the Fathers Chapter 10: Venom Returns',),
#  ('Sins of the Fathers Chapter 11: Carnage',),
#  ('Sins of the Fathers Chapter 12: The Spot',),
#  ('Sins of the Fathers Chapter 13: Goblin War!',),
#  ('Sins of the Fathers Chapter 14: The Turning Point',),
#  ('Sins of the Fathers Chapter 1: Doctor Strange',),
#  ('Sins of the Fathers Chapter 2: Make a Wish',),
#  ('Sins of the Fathers Chapter 3: Attack of the Octobot',),
#  ('Sins of the Fathers Chapter 4: Enter the Green Goblin',),
#  ('Sins of the Fathers Chapter 5: The Rocket Racer',),
#  ('Sins of the Fathers Chapter 6: Framed',),
#  ('Sins of the Fathers Chapter 7: The Man Without Fear',),
#  ('Sins of the Fathers Chapter 8: The Ultimate Slayer',),
#  ('Sins of the Fathers Chapter 9: Tombstone',),
#  ('Six Forgotten Warriors Chapter 1',),
#  ('Six Forgotten Warriors Chapter 2: Unclaimed Legacy',),
#  ('Six Forgotten Warriors Chapter 3: Secrets of the Six',),
#  ('Six Forgotten Warriors Chapter 4: The Six Fight Again',),
#  ('Six Forgotten Warriors Chapter 5: The Price of Heroism',),
#  ('Spider Wars, Chapter 1: I Really, Really Hate Clones',),
#  ('Spider Wars, Chapter 2: Farewell Spider-Man',),
#  ('The Alien Costume: Part 1',),
#  ('The Alien Costume: Part 2',),
#  ('The Alien Costume: Part 3',),
#  ('The Hobgoblin: Part 1',),
#  ('The Hobgoblin: Part 2',),
#  ('The Menace of Mysterio',),
#  ('The Return of Hydro-Man: Part 2',),
#  ('The Return of the Spider-Slayers',),
#  ('The Spider Slayer',),
#  ('The Sting of the Scorpion',),
#  ('The Wedding',),
#  ('Flash Memory',),
#  ('Head Over Heels',),
#  ('Heroes and Villains',),
#  ('Keeping Secrets',),
#  ('Law of the Jungle',),
#  ('Mind Games: Part 1',),
#  ('Mind Games: Part 2',),
#  ('Royal Scam',),
#  ('Spider-Man Dis-Abled',),
#  ('Sword of Shikata',),
#  ('The Party',),
#  ('Tight Squeeze',),
#  ('When Sparks Fly',),
#  ('Enter the Hunter!',),
#  ('The Amazing Spider-Man',),
#  ('The Spectacular Spider-Man',),
#  ('Watch Movie Free Online',),
#  ('Marvel 616',),
#  ('Spider-Man: Identity',),
#  ('Survival of the Fittest',),
#  ('The Origin of Spider-Man',),
#  ('Spider-Man vs Mysterio: Far From Home',),
#  ('The Spider-Man 2',),
#  ('Spider-Man: No Way Home',),
#  ('Brand New Day',),
#  ('The Cellar',),
#  ('GHETTO SPIDER-MAN!',),
#  ('The Road to Goblin War',),
#  ('Goblin War Part One',),
#  ('Goblin War Part Two',),
#  ('Goblin War Part Three',),
#  ('Goblin War Part Four',),
#  ("Marvel's Spider-Man",),
#  ('Japanese Spider-Man',),
#  ("Spider-Man Forgets About Aunt May's Milk",),
#  ('Interactions',),
#  ('The Amazing Spider-Man 2',),
#  ('Natural Selection',),
#  ('Market Forces',),
#  ('Competition',),
#  ('The Invisible Hand',),
#  ('Catalysts',),
#  ('Reaction',),
#  ('Web of Venom',),
#  ('Group Therapy',),
#  ('Persona',),
#  ('The Uncertainty Principle',),
#  ('Amazing Friends',),
#  ('Intervention',),
#  ('Nature vs. Nurture',),
#  ('Vengeance of Venom',),
#  ('Spider-Man 4 Fan Film',),
#  ('Spider-Man Unmasked',),
#  ('Generations',),
#  ('Maximum Venom',),
#  ('Spider-Man: Excelsior in Purgatory',),
#  ('Blueprints',),
#  ('Destructive Testing',),
#  ('Reinforcement',),
#  ('Shear Strength',),
#  ('First Steps',),
#  ('The Spider-Man Team-Up!',),
#  ('The Lego Batman, Spider-Man, & Chewbacca Movie',),
#  ('The Robin',),
#  ('The Lego Batman & Spider-Man Movie',),
#  ('The Lego Batman & Spider-Man Movie 2',),
#  ('The Lego Batman, Spider-Man, & Superman Movie',),
#  ('Growing Pains',),
#  ('Identity Crisis',),
#  ('Avengers: Infinity War Demastered',),
#  ('Accomplices',),
#  ('Gangland',),
#  ('Probable Cause',),
#  ('Subtext',),
#  ('Opening Night',),
#  ('Final Curtain',),
#  ('SPIDER-MAN PRANK IN REAL LIFE ON FRIENDS!!',),
#  ('She Caught Me Kissing Her Best Friend',),
#  ('Fear and Loathing in Vegas Stakes',),
#  ('The Amazing Spider-Man 2 (2014)',),
#  ('The LJN Library',),
#  ('Spider-Woman, Agent of S.W.O.R.D.',),
#  ('Ultimate Spider-Man',),
#  ('Episode #1.1',),
#  ('I Love You, Iron Man/Ben 10 Franklin',),
#  ('Major League of Extraordinary Gentlemen',),
#  ('Great Power',),
#  ('Great Responsibility',),
#  ('Doomed',),
#  ('Venom',),
#  ('Flight of the Iron Spider',),
#  ('Why I Hate the Gym',),
#  ('Top 11 Dumbasses in Distress',),
#  ('Venomous',),
#  ('Strange',),
#  ('Freaky',),
#  ('If Superheroes Were Real',),
#  ('Exclusive',),
#  ('Back in Black',),
#  ('Me Time',),
#  ('Field Trip',),
#  ('For Your Eye Only',),
#  ('Beetle Mania',),
#  ('Snow Day',),
#  ('Damage',),
#  ('Home Sick Hulk',),
#  ('Run Pig Run',),
#  ('I Am Spider-Man',),
#  ('The Iron Octopus',),
#  ('Not a Toy',),
#  ('Attack of the Beetle',),
#  ('Revealed',),
#  ('Rise of the Goblin',),
#  ('How Spider-Man 3 Should Have Ended',),
#  ('New Avengers',),
#  ('The Lizard',),
#  ('How Iron Man Should Have Ended',),
#  ('Awesome',),
#  ('Spider-Man: Homecoming',),
#  ('iChronicle/Hulk Smash',),
#  ('Electro',),
#  ("Hi, I'm a Marvel... and I'm a DC",),
#  ('The Rhino',),
#  ('The Amazing Spider-Minaj/Go, Dragon Ball, Go!',),
#  ('Hawkeye',),
#  ('Sinister Six',),
#  ('Spidah-Man',),
#  ('Carnage',),
#  ('Journey of the Iron Fist',),
#  ('House Arrest',),
#  ('The Man-Wolf',),
#  ('Marvel Mash-Up',),
#  ('The Incredible Spider-Hulk',),
#  ('Game Over',),
#  ('Second Chance Hero',),
#  ('Stan by Me',),
#  ('Swarm',),
#  ('Itsy Bitsy Spider-Man',),
#  ('Ultimate Deadpool',),
#  ('Venom Bomb',),
#  ('The Parent Trap',),
#  ('Guardians of the Galaxy',),
#  ('The Howling Commandos',),
#  ('Sandman Returns',),
#  ('Superheroes: A Never-Ending Battle',),
#  ('The Collector',),
#  ('The Avenging Spider-Man: Part 1',),
#  ('The Avenging Spider-Man: Part 2',),
#  ('Agent Venom',),
#  ('Cloak and Dagger',),
#  ('The Next Iron Spider',),
#  ('The Vulture',),
#  ('The Savage Spider-Man',),
#  ('New Warriors',),
#  ('The Return of the Guardians of the Galaxy',),
#  ('The Spider-Verse: Part 2',),
#  ('The Spider-Verse: Part 3',),
#  ('The Spider-Verse: Part 4',),
#  ('The Spider-Verse: Part 1',),
#  ('Return of the Sinister Six',),
#  ('Ultimate',),
#  ('Blade',),
#  ('SHIELD Academy',),
#  ('Halloween Night at the Museum',),
#  ('The Venom Within',),
#  ('Nightmare on Christmas',),
#  ('Ant-Man',),
#  ('Attack of the Synthezoids',),
#  ('The Revenge of Arnim Zola',),
#  ('Burrito Run',),
#  ('Contest of the Champions: Part 1',),
#  ('Contest of the Champions: Part 2',),
#  ('Contest of the Champions: Part 3',),
#  ('Contest of the Champions: Part 4',),
#  ('How the Amazing Spider-Man Should Have Ended',),
#  ('How the Avengers Should Have Ended',),
#  ('How the Amazing Spider-Man 2 Should Have Ended',),
#  ('Rampaging Rhino',),
#  ('The Avenging Spider-Man',),
#  ('Spidey, I Blew Up the Dinosaur',),
#  ('Web of the Spider-Man',),
#  ('Super Café: And the Reboot Goes To...',),
#  ('Inhumanity',),
#  ('Hydra Attacks: Part 1',),
#  ('Marvel Knights: Spider-Man',),
#  ('Marvel Zombies vs. Army of Darkness',),
#  ('The Spectacular Lego Spider-Man',),
#  ('Spider-Man vs. Darth Maul',),
#  ('Hydra Attacks: Part 2',),
#  ('Miles from Home',),
#  ('Iron Vulture',),
#  ('Lizards',),
#  ('Double Agent Venom',),
#  ('Beached',),
#  ('Anti-Venom',),
#  ('Force of Nature',),
#  ('Spider-Man: Vengeance',),
#  ('The New Sinister 6: Part 1',),
#  ('The New Sinister 6: Part 2',),
#  ('Agent Web',),
#  ('The Symbiote Saga: Part 1',),
#  ('The Symbiote Saga: Part 2',),
#  ('The Symbiote Saga: Part 3',),
#  ('Return to the Spider-Verse: Part 1',),
#  ('Return to the Spider-Verse: Part 2',),
#  ('Return to the Spider-Verse: Part 3',),
#  ('Return to the Spider-Verse: Part 4',),
#  ('Strange Little Halloween',),
#  ('The Spider Slayers: Part 1',),
#  ('The Spider Slayers: Part 2',),
#  ('The Spider Slayers: Part 3',),
#  ('The Moon Knight Before Christmas',),
#  ('Graduation Day: Part 1',),
#  ('Graduation Day: Part 2',),
#  ('Spider-Man: Far from Home',),
#  ('Marvel Video Comics',),
#  ('Spider-Man: Balance Act',),
#  ('Horizon High: Part One',),
#  ('Once Bitten: A Spider-Man Story',),
#  ('Horizon High: Part Two',),
#  ('Origins',),
#  ('The Amazing Spider-man Movies',),
#  ('Osborn Academy',),
#  ('Party Animals',),
#  ('The Living Brain',),
#  ('The Hobgoblin: Part One',),
#  ('Sandman',),
#  ("CF Picture's Spider-Man",),
#  ('Symbiotic Relationship',),
#  ('The League of Extraordinary Gentlemen',),
#  ('Spider-Island: Part One',),
#  ('The Rise of Doc Ock: Part Three',),
#  ('Take Two',),
#  ('How I Thwipped My Summer Vacation',),
#  ('Spider-Island: Part Five',),
#  ('The Rise of Doc Ock: Part Four',),
#  ('Rise Above It All',),
#  ("Dead Man's Party",),
#  ('Stark Expo',),
#  ('The Ultimate LEGO Spider-Man (BMCU)',),
#  ('Spider-Island: Part Two',),
#  ('Halloween Moon',),
#  ('Between an Ock and a Hard Place',),
#  ('A Day in the Life',),
#  ('Venom Returns',),
#  ('School of Hard Knocks',),
#  ('Bring on the Bad Guys: Part Four',),
#  ('Bring on the Bad Guys: Part Three',),
#  ('The Marvelous Spider-Man 3: Empire of Blood',),
#  ('Spider-Island: Part Four',),
#  ('Marvel Super Hero Adventures',),
#  ("Kraven's Amazing Hunt",),
#  ('How Spider-Man Into the Spider-Verse Should Have Ended',),
#  ('The Rise of Doc Ock: Part One',),
#  ('The Hobgoblin: Part Two',),
#  ('Spider-Man on Ice',),
#  ('Screwball Live',),
#  ("CF Picture's Spider-Man: Dissension",),
#  ('Brain Drain',),
#  ('Vibranium Curtain: Part Two',),
#  ('Bring on the Bad Guys: Part Two',),
#  ('Spider-Island: Part Three',),
#  ('How Infinity War Should Have Ended',),
#  ('How Spider-Man Homecoming Should Have Ended',),
#  ('The Rise of Doc Ock: Part Two',),
#  ('Bring on the Bad Guys: Part One',),
#  ('Avengers: Legacy',)]

# %%
# %%sql
#
# SELECT Names_.name_, Titles.primary_title, Titles.title_type, Titles.start_year
# FROM Had_role
# INNER JOIN Titles ON Had_role.title_id = Titles.title_id
# INNER JOIN Names_ ON Had_role.name_id = Names_.name_id
# WHERE (Had_role.role_ LIKE "Spider-Man")
# ORDER BY Names_.name_, Titles.primary_title;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 310 rows affected.
# [('Aaron Schoenke', 'Spider-Man vs. Darth Maul', 'tvEpisode', 2015),
#  ('Andrew Garfield', 'The Amazing Spider-Man', 'movie', 2012),
#  ('Andrew Garfield', 'The Amazing Spider-Man 2', 'movie', 2014),
#  ('Andy Richter', 'Major League of Extraordinary Gentlemen', 'tvEpisode', 2011),
#  ('Christopher Daniel Barnes', 'Day of the Chameleon', 'tvEpisode', 1995),
#  ('Christopher Daniel Barnes', 'Doctor Octopus: Armed and Dangerous', 'tvEpisode', 1995),
#  ('Christopher Daniel Barnes', 'Kraven the Hunter', 'tvEpisode', 1995),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 10: The Immortal Vampire', 'tvEpisode', 1996),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 11: Tablet of Time', 'tvEpisode', 1995),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 12: Ravages of Time', 'tvEpisode', 1995),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 13: Shriek of the Vulture', 'tvEpisode', 1996),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 14: The Final Nightmare', 'tvEpisode', 1996),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 1: The Insidious Six', 'tvEpisode', 1995),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 2: Battle of the Insidious Six', 'tvEpisode', 1995),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 3: Hydro-Man', 'tvEpisode', 1995),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 4: The Mutant Agenda', 'tvEpisode', 1995),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 5: Mutants Revenge', 'tvEpisode', 1995),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 6: Morbius', 'tvEpisode', 1995),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 7: Enter the Punisher', 'tvEpisode', 1995),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 8: Duel of the Hunters', 'tvEpisode', 1995),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 9: Blade the Vampire Hunter', 'tvEpisode', 1996),
#  ('Christopher Daniel Barnes', 'Night of the Lizard', 'tvEpisode', 1994),
#  ('Christopher Daniel Barnes', 'Partners in Danger Chapter 10: Lizard King', 'tvEpisode', 1997),
#  ('Christopher Daniel Barnes', 'Partners in Danger Chapter 11: The Prowler', 'tvEpisode', 1997),
#  ('Christopher Daniel Barnes', 'Partners in Danger Chapter 1: Guilty', 'tvEpisode', 1997),
#  ('Christopher Daniel Barnes', 'Partners in Danger Chapter 2: The Cat', 'tvEpisode', 1997),
#  ('Christopher Daniel Barnes', 'Partners in Danger Chapter 3: The Black Cat', 'tvEpisode', 1997),
#  ('Christopher Daniel Barnes', 'Partners in Danger Chapter 4: Return of Kraven', 'tvEpisode', 1997),
#  ('Christopher Daniel Barnes', 'Partners in Danger Chapter 5: Partners', 'tvEpisode', 1997),
#  ('Christopher Daniel Barnes', 'Partners in Danger Chapter 6: The Awakening', 'tvEpisode', 1997),
#  ('Christopher Daniel Barnes', 'Partners in Danger Chapter 7: The Vampire Queen', 'tvEpisode', 1997),
#  ('Christopher Daniel Barnes', 'Partners in Danger Chapter 8: The Return of the Green Goblin', 'tvEpisode', 1997),
#  ('Christopher Daniel Barnes', 'Partners in Danger Chapter 9: The Haunting of Mary Jane', 'tvEpisode', 1997),
#  ('Christopher Daniel Barnes', 'Secret Wars, Chapter 1: Arrival', 'tvEpisode', 1997),
#  ('Christopher Daniel Barnes', 'Secret Wars, Chapter 2: The Gauntlet of the Red Skull', 'tvEpisode', 1997),
#  ('Christopher Daniel Barnes', 'Secret Wars, Chapter 3: Doom', 'tvEpisode', 1997),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 10: Venom Returns', 'tvEpisode', 1996),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 11: Carnage', 'tvEpisode', 1996),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 12: The Spot', 'tvEpisode', 1996),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 13: Goblin War!', 'tvEpisode', 1996),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 14: The Turning Point', 'tvEpisode', 1996),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 1: Doctor Strange', 'tvEpisode', 1996),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 2: Make a Wish', 'tvEpisode', 1996),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 3: Attack of the Octobot', 'tvEpisode', 1996),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 4: Enter the Green Goblin', 'tvEpisode', 1996),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 5: The Rocket Racer', 'tvEpisode', 1996),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 6: Framed', 'tvEpisode', 1996),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 7: The Man Without Fear', 'tvEpisode', 1996),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 8: The Ultimate Slayer', 'tvEpisode', 1996),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 9: Tombstone', 'tvEpisode', 1996),
#  ('Christopher Daniel Barnes', 'Six Forgotten Warriors Chapter 1', 'tvEpisode', 1997),
#  ('Christopher Daniel Barnes', 'Six Forgotten Warriors Chapter 2: Unclaimed Legacy', 'tvEpisode', 1997),
#  ('Christopher Daniel Barnes', 'Six Forgotten Warriors Chapter 3: Secrets of the Six', 'tvEpisode', 1997),
#  ('Christopher Daniel Barnes', 'Six Forgotten Warriors Chapter 4: The Six Fight Again', 'tvEpisode', 1997),
#  ('Christopher Daniel Barnes', 'Six Forgotten Warriors Chapter 5: The Price of Heroism', 'tvEpisode', 1997),
#  ('Christopher Daniel Barnes', 'Spider Wars, Chapter 1: I Really, Really Hate Clones', 'tvEpisode', 1998),
#  ('Christopher Daniel Barnes', 'Spider Wars, Chapter 2: Farewell Spider-Man', 'tvEpisode', 1998),
#  ('Christopher Daniel Barnes', 'Spider-Man: The Animated Series', 'tvSeries', 1994),
#  ('Christopher Daniel Barnes', 'The Alien Costume: Part 1', 'tvEpisode', 1995),
#  ('Christopher Daniel Barnes', 'The Alien Costume: Part 2', 'tvEpisode', 1995),
#  ('Christopher Daniel Barnes', 'The Alien Costume: Part 3', 'tvEpisode', 1995),
#  ('Christopher Daniel Barnes', 'The Hobgoblin: Part 1', 'tvEpisode', 1995),
#  ('Christopher Daniel Barnes', 'The Hobgoblin: Part 2', 'tvEpisode', 1995),
#  ('Christopher Daniel Barnes', 'The Menace of Mysterio', 'tvEpisode', 1995),
#  ('Christopher Daniel Barnes', 'The Return of Hydro-Man: Part 2', 'tvEpisode', 1997),
#  ('Christopher Daniel Barnes', 'The Return of the Spider-Slayers', 'tvEpisode', 1995),
#  ('Christopher Daniel Barnes', 'The Spider Slayer', 'tvEpisode', 1995),
#  ('Christopher Daniel Barnes', 'The Sting of the Scorpion', 'tvEpisode', 1995),
#  ('Christopher Daniel Barnes', 'The Wedding', 'tvEpisode', 1997),
#  ('Cole Howard', 'Marvel Super Hero Adventures', 'tvMiniSeries', 2017),
#  ('Cole Howard', 'Marvel Video Comics', 'tvMiniSeries', 2016),
#  ('Doug Walker', 'The Amazing Spider-Man 2', 'tvEpisode', 2020),
#  ('Doug Walker', 'The League of Extraordinary Gentlemen', 'tvEpisode', 2018),
#  ('Drake Bell', 'Agent Venom', 'tvEpisode', 2014),
#  ('Drake Bell', 'Agent Web', 'tvEpisode', 2016),
#  ('Drake Bell', 'Ant-Man', 'tvEpisode', 2015),
#  ('Drake Bell', 'Anti-Venom', 'tvEpisode', 2016),
#  ('Drake Bell', 'Attack of the Beetle', 'tvEpisode', 2012),
#  ('Drake Bell', 'Attack of the Synthezoids', 'tvEpisode', 2015),
#  ('Drake Bell', 'Awesome', 'tvEpisode', 2012),
#  ('Drake Bell', 'Back in Black', 'tvEpisode', 2012),
#  ('Drake Bell', 'Beached', 'tvEpisode', 2016),
#  ('Drake Bell', 'Beetle Mania', 'tvEpisode', 2012),
#  ('Drake Bell', 'Blade', 'tvEpisode', 2013),
#  ('Drake Bell', 'Burrito Run', 'tvEpisode', 2015),
#  ('Drake Bell', 'Carnage', 'tvEpisode', 2013),
#  ('Drake Bell', 'Cloak and Dagger', 'tvEpisode', 2014),
#  ('Drake Bell', 'Contest of the Champions: Part 1', 'tvEpisode', 2015),
#  ('Drake Bell', 'Contest of the Champions: Part 2', 'tvEpisode', 2015),
#  ('Drake Bell', 'Contest of the Champions: Part 3', 'tvEpisode', 2015),
#  ('Drake Bell', 'Contest of the Champions: Part 4', 'tvEpisode', 2015),
#  ('Drake Bell', 'Damage', 'tvEpisode', 2012),
#  ('Drake Bell', 'Doomed', 'tvEpisode', 2012),
#  ('Drake Bell', 'Double Agent Venom', 'tvEpisode', 2016),
#  ('Drake Bell', 'Electro', 'tvEpisode', 2013),
#  ('Drake Bell', 'Exclusive', 'tvEpisode', 2012),
#  ('Drake Bell', 'Field Trip', 'tvEpisode', 2012),
#  ('Drake Bell', 'Flight of the Iron Spider', 'tvEpisode', 2012),
#  ('Drake Bell', 'For Your Eye Only', 'tvEpisode', 2012),
#  ('Drake Bell', 'Force of Nature', 'tvEpisode', 2016),
#  ('Drake Bell', 'Freaky', 'tvEpisode', 2012),
#  ('Drake Bell', 'Game Over', 'tvEpisode', 2013),
#  ('Drake Bell', 'Graduation Day: Part 1', 'tvEpisode', 2017),
#  ('Drake Bell', 'Graduation Day: Part 2', 'tvEpisode', 2017),
#  ('Drake Bell', 'Great Power', 'tvEpisode', 2012),
#  ('Drake Bell', 'Great Responsibility', 'tvEpisode', 2012),
#  ('Drake Bell', 'Guardians of the Galaxy', 'tvEpisode', 2013),
#  ('Drake Bell', 'Halloween Night at the Museum', 'tvEpisode', 2014),
#  ('Drake Bell', 'Hawkeye', 'tvEpisode', 2013),
#  ('Drake Bell', 'Home Sick Hulk', 'tvEpisode', 2012),
#  ('Drake Bell', 'House Arrest', 'tvEpisode', 2013),
#  ('Drake Bell', 'Hydra Attacks: Part 1', 'tvEpisode', 2016),
#  ('Drake Bell', 'Hydra Attacks: Part 2', 'tvEpisode', 2016),
#  ('Drake Bell', 'I Am Spider-Man', 'tvEpisode', 2012),
#  ('Drake Bell', 'Inhumanity', 'tvEpisode', 2015),
#  ('Drake Bell', 'Iron Vulture', 'tvEpisode', 2016),
#  ('Drake Bell', 'Itsy Bitsy Spider-Man', 'tvEpisode', 2013),
#  ('Drake Bell', 'Journey of the Iron Fist', 'tvEpisode', 2013),
#  ('Drake Bell', 'Kraven the Hunter', 'tvEpisode', 2013),
#  ('Drake Bell', 'Lizards', 'tvEpisode', 2016),
#  ('Drake Bell', 'Me Time', 'tvEpisode', 2012),
#  ('Drake Bell', 'Miles from Home', 'tvEpisode', 2016),
#  ('Drake Bell', 'New Avengers', 'tvEpisode', 2012),
#  ('Drake Bell', 'New Warriors', 'tvEpisode', 2014),
#  ('Drake Bell', 'Nightmare on Christmas', 'tvEpisode', 2014),
#  ('Drake Bell', 'Not a Toy', 'tvEpisode', 2012),
#  ('Drake Bell', 'Rampaging Rhino', 'tvEpisode', 2015),
#  ('Drake Bell', 'Return of the Sinister Six', 'tvEpisode', 2013),
#  ('Drake Bell', 'Return to the Spider-Verse: Part 1', 'tvEpisode', 2016),
#  ('Drake Bell', 'Return to the Spider-Verse: Part 2', 'tvEpisode', 2016),
#  ('Drake Bell', 'Return to the Spider-Verse: Part 3', 'tvEpisode', 2016),
#  ('Drake Bell', 'Return to the Spider-Verse: Part 4', 'tvEpisode', 2016),
#  ('Drake Bell', 'Revealed', 'tvEpisode', 2012),
#  ('Drake Bell', 'Rise of the Goblin', 'tvEpisode', 2012),
#  ('Drake Bell', 'Run Pig Run', 'tvEpisode', 2012),
#  ('Drake Bell', 'SHIELD Academy', 'tvEpisode', 2015),
#  ('Drake Bell', 'Sandman Returns', 'tvEpisode', 2013),
#  ('Drake Bell', 'Second Chance Hero', 'tvEpisode', 2013),
#  ('Drake Bell', 'Sinister Six', 'tvEpisode', 2013),
#  ('Drake Bell', 'Snow Day', 'tvEpisode', 2012),
#  ('Drake Bell', 'Spidah-Man', 'tvEpisode', 2013),
#  ('Drake Bell', 'Spidey, I Blew Up the Dinosaur', 'tvEpisode', 2015),
#  ('Drake Bell', 'Stan by Me', 'tvEpisode', 2013),
#  ('Drake Bell', 'Strange', 'tvEpisode', 2012),
#  ('Drake Bell', 'Strange Little Halloween', 'tvEpisode', 2016),
#  ('Drake Bell', 'Swarm', 'tvEpisode', 2013),
#  ('Drake Bell', 'The Avenging Spider-Man: Part 1', 'tvEpisode', 2014),
#  ('Drake Bell', 'The Avenging Spider-Man: Part 2', 'tvEpisode', 2014),
#  ('Drake Bell', 'The Collector', 'tvEpisode', 2013),
#  ('Drake Bell', 'The Howling Commandos', 'tvEpisode', 2013),
#  ('Drake Bell', 'The Incredible Spider-Hulk', 'tvEpisode', 2013),
#  ('Drake Bell', 'The Iron Octopus', 'tvEpisode', 2012),
#  ('Drake Bell', 'The Lizard', 'tvEpisode', 2013),
#  ('Drake Bell', 'The Man-Wolf', 'tvEpisode', 2013),
#  ('Drake Bell', 'The Moon Knight Before Christmas', 'tvEpisode', 2016),
#  ('Drake Bell', 'The New Sinister 6: Part 1', 'tvEpisode', 2016),
#  ('Drake Bell', 'The New Sinister 6: Part 2', 'tvEpisode', 2016),
#  ('Drake Bell', 'The Next Iron Spider', 'tvEpisode', 2014),
#  ('Drake Bell', 'The Parent Trap', 'tvEpisode', 2013),
#  ('Drake Bell', 'The Return of the Guardians of the Galaxy', 'tvEpisode', 2014),
#  ('Drake Bell', 'The Revenge of Arnim Zola', 'tvEpisode', 2015),
#  ('Drake Bell', 'The Rhino', 'tvEpisode', 2013),
#  ('Drake Bell', 'The Savage Spider-Man', 'tvEpisode', 2014),
#  ('Drake Bell', 'The Spider Slayers: Part 1', 'tvEpisode', 2016),
#  ('Drake Bell', 'The Spider Slayers: Part 2', 'tvEpisode', 2016),
#  ('Drake Bell', 'The Spider Slayers: Part 3', 'tvEpisode', 2016),
#  ('Drake Bell', 'The Spider-Verse: Part 1', 'tvEpisode', 2015),
#  ('Drake Bell', 'The Spider-Verse: Part 2', 'tvEpisode', 2015),
#  ('Drake Bell', 'The Spider-Verse: Part 3', 'tvEpisode', 2015),
#  ('Drake Bell', 'The Spider-Verse: Part 4', 'tvEpisode', 2015),
#  ('Drake Bell', 'The Symbiote Saga: Part 1', 'tvEpisode', 2016),
#  ('Drake Bell', 'The Symbiote Saga: Part 2', 'tvEpisode', 2016),
#  ('Drake Bell', 'The Symbiote Saga: Part 3', 'tvEpisode', 2016),
#  ('Drake Bell', 'The Venom Within', 'tvEpisode', 2013),
#  ('Drake Bell', 'The Vulture', 'tvEpisode', 2014),
#  ('Drake Bell', 'Ultimate', 'tvEpisode', 2013),
#  ('Drake Bell', 'Ultimate Deadpool', 'tvEpisode', 2013),
#  ('Drake Bell', 'Ultimate Spider-Man', 'tvSeries', 2012),
#  ('Drake Bell', 'Venom', 'tvEpisode', 2012),
#  ('Drake Bell', 'Venom Bomb', 'tvEpisode', 2013),
#  ('Drake Bell', 'Venomous', 'tvEpisode', 2012),
#  ('Drake Bell', 'Why I Hate the Gym', 'tvEpisode', 2012),
#  ('Forrest Whaley', 'The Lego Batman, Spider-Man, & Chewbacca Movie', 'tvEpisode', 2007),
#  ('Forrest Whaley', 'The Robin', 'tvEpisode', 2008),
#  ('Forrest Whaley', 'The Spider-Man Team-Up!', 'tvEpisode', 2007),
#  ('Ian Hecox', 'If Superheroes Were Real', 'tvEpisode', 2011),
#  ('JP Karliak', 'Marvel Mash-Up', 'tvMiniSeries', 2012),
#  ('Josh Keaton', 'Accomplices', 'tvEpisode', 2009),
#  ('Josh Keaton', 'Blueprints', 'tvEpisode', 2009),
#  ('Josh Keaton', 'Catalysts', 'tvEpisode', 2008),
#  ('Josh Keaton', 'Competition', 'tvEpisode', 2008),
#  ('Josh Keaton', 'Destructive Testing', 'tvEpisode', 2009),
#  ('Josh Keaton', 'Final Curtain', 'tvEpisode', 2009),
#  ('Josh Keaton', 'First Steps', 'tvEpisode', 2009),
#  ('Josh Keaton', 'Gangland', 'tvEpisode', 2009),
#  ('Josh Keaton', 'Group Therapy', 'tvEpisode', 2008),
#  ('Josh Keaton', 'Growing Pains', 'tvEpisode', 2009),
#  ('Josh Keaton', 'Identity Crisis', 'tvEpisode', 2009),
#  ('Josh Keaton', 'Interactions', 'tvEpisode', 2008),
#  ('Josh Keaton', 'Intervention', 'tvEpisode', 2008),
#  ('Josh Keaton', 'Market Forces', 'tvEpisode', 2008),
#  ('Josh Keaton', 'Natural Selection', 'tvEpisode', 2008),
#  ('Josh Keaton', 'Nature vs. Nurture', 'tvEpisode', 2008),
#  ('Josh Keaton', 'Opening Night', 'tvEpisode', 2009),
#  ('Josh Keaton', 'Persona', 'tvEpisode', 2008),
#  ('Josh Keaton', 'Probable Cause', 'tvEpisode', 2009),
#  ('Josh Keaton', 'Reaction', 'tvEpisode', 2008),
#  ('Josh Keaton', 'Reinforcement', 'tvEpisode', 2009),
#  ('Josh Keaton', 'Shear Strength', 'tvEpisode', 2009),
#  ('Josh Keaton', 'Subtext', 'tvEpisode', 2009),
#  ('Josh Keaton', 'Survival of the Fittest', 'tvEpisode', 2008),
#  ('Josh Keaton', 'The Invisible Hand', 'tvEpisode', 2008),
#  ('Josh Keaton', 'The Spectacular Spider-Man', 'tvSeries', 2008),
#  ('Josh Keaton', 'The Uncertainty Principle', 'tvEpisode', 2008),
#  ('Mikey Day', 'I Love You, Iron Man/Ben 10 Franklin', 'tvEpisode', 2010),
#  ('Mikey Day', 'The Amazing Spider-Minaj/Go, Dragon Ball, Go!', 'tvEpisode', 2012),
#  ('Mikey Day', 'iChronicle/Hulk Smash', 'tvEpisode', 2012),
#  ('Neil Patrick Harris', 'Flash Memory', 'tvEpisode', 2003),
#  ('Neil Patrick Harris', 'Head Over Heels', 'tvEpisode', 2003),
#  ('Neil Patrick Harris', 'Heroes and Villains', 'tvEpisode', 2003),
#  ('Neil Patrick Harris', 'Keeping Secrets', 'tvEpisode', 2003),
#  ('Neil Patrick Harris', 'Law of the Jungle', 'tvEpisode', 2003),
#  ('Neil Patrick Harris', 'Mind Games: Part 1', 'tvEpisode', 2003),
#  ('Neil Patrick Harris', 'Mind Games: Part 2', 'tvEpisode', 2003),
#  ('Neil Patrick Harris', 'Royal Scam', 'tvEpisode', 2003),
#  ('Neil Patrick Harris', 'Spider-Man', 'tvSeries', 2003),
#  ('Neil Patrick Harris', 'Spider-Man Dis-Abled', 'tvEpisode', 2003),
#  ('Neil Patrick Harris', 'Sword of Shikata', 'tvEpisode', 2003),
#  ('Neil Patrick Harris', 'The Party', 'tvEpisode', 2003),
#  ('Neil Patrick Harris', 'Tight Squeeze', 'tvEpisode', 2003),
#  ('Neil Patrick Harris', 'When Sparks Fly', 'tvEpisode', 2003),
#  ('Rino Romano', 'Cry Vulture', 'tvEpisode', 2001),
#  ('Rino Romano', 'Deadly Choices', 'tvEpisode', 2000),
#  ('Rino Romano', 'Destiny Unleashed', 'tvEpisode', 2001),
#  ('Rino Romano', 'Enter the Hunter!', 'tvEpisode', 2001),
#  ('Rino Romano', 'Ill-Met by Moonlight', 'tvEpisode', 2001),
#  ('Rino Romano', 'Matters of the Heart', 'tvEpisode', 2001),
#  ('Rino Romano', 'One Is the Loneliest Number', 'tvEpisode', 2001),
#  ('Rino Romano', 'Sins of the Fathers', 'tvEpisode', 2001),
#  ('Rino Romano', 'Spider-Man Unlimited', 'tvSeries', 1999),
#  ('Rino Romano', 'Steel Cold Heart', 'tvEpisode', 2001),
#  ('Rino Romano', 'Sustenance', 'tvEpisode', 2001),
#  ('Rino Romano', 'Where Evil Nests', 'tvEpisode', 1999),
#  ('Rino Romano', 'Worlds Apart: Part 1', 'tvEpisode', 1999),
#  ('Rino Romano', 'Worlds Apart: Part 2', 'tvEpisode', 1999),
#  ('Robbie Daymond', 'A Day in the Life', 'tvEpisode', 2017),
#  ('Robbie Daymond', 'Amazing Friends', 'tvEpisode', 2020),
#  ('Robbie Daymond', 'Between an Ock and a Hard Place', 'tvEpisode', 2018),
#  ('Robbie Daymond', 'Brain Drain', 'tvEpisode', 2018),
#  ('Robbie Daymond', 'Brand New Day', 'tvEpisode', 2019),
#  ('Robbie Daymond', 'Bring on the Bad Guys: Part Four', 'tvEpisode', 2018),
#  ('Robbie Daymond', 'Bring on the Bad Guys: Part One', 'tvEpisode', 2018),
#  ('Robbie Daymond', 'Bring on the Bad Guys: Part Three', 'tvEpisode', 2018),
#  ('Robbie Daymond', 'Bring on the Bad Guys: Part Two', 'tvEpisode', 2018),
#  ('Robbie Daymond', "Dead Man's Party", 'tvEpisode', 2018),
#  ('Robbie Daymond', 'Generations', 'tvEpisode', 2020),
#  ('Robbie Daymond', 'Goblin War Part Four', 'tvEpisode', 2019),
#  ('Robbie Daymond', 'Goblin War Part One', 'tvEpisode', 2019),
#  ('Robbie Daymond', 'Goblin War Part Three', 'tvEpisode', 2019),
#  ('Robbie Daymond', 'Goblin War Part Two', 'tvEpisode', 2019),
#  ('Robbie Daymond', 'Halloween Moon', 'tvEpisode', 2017),
#  ('Robbie Daymond', 'Horizon High: Part One', 'tvEpisode', 2017),
#  ('Robbie Daymond', 'Horizon High: Part Two', 'tvEpisode', 2017),
#  ('Robbie Daymond', 'How I Thwipped My Summer Vacation', 'tvEpisode', 2018),
#  ('Robbie Daymond', "Kraven's Amazing Hunt", 'tvEpisode', 2017),
#  ('Robbie Daymond', 'Maximum Venom', 'tvEpisode', 2020),
#  ('Robbie Daymond', 'Origins', 'tvEpisode', 2017),
#  ('Robbie Daymond', 'Osborn Academy', 'tvEpisode', 2017),
#  ('Robbie Daymond', 'Party Animals', 'tvEpisode', 2017),
#  ('Robbie Daymond', 'Rise Above It All', 'tvEpisode', 2018),
#  ('Robbie Daymond', 'Sandman', 'tvEpisode', 2017),
#  ('Robbie Daymond', 'School of Hard Knocks', 'tvEpisode', 2018),
#  ('Robbie Daymond', 'Screwball Live', 'tvEpisode', 2017),
#  ('Robbie Daymond', 'Spider-Island: Part Five', 'tvEpisode', 2018),
#  ('Robbie Daymond', 'Spider-Island: Part Four', 'tvEpisode', 2018),
#  ('Robbie Daymond', 'Spider-Island: Part One', 'tvEpisode', 2018),
#  ('Robbie Daymond', 'Spider-Island: Part Three', 'tvEpisode', 2018),
#  ('Robbie Daymond', 'Spider-Island: Part Two', 'tvEpisode', 2018),
#  ('Robbie Daymond', 'Spider-Man', 'tvSeries', 2017),
#  ('Robbie Daymond', 'Spider-Man Unmasked', 'tvEpisode', 2020),
#  ('Robbie Daymond', 'Spider-Man on Ice', 'tvEpisode', 2017),
#  ('Robbie Daymond', 'Stark Expo', 'tvEpisode', 2017),
#  ('Robbie Daymond', 'Symbiotic Relationship', 'tvEpisode', 2017),
#  ('Robbie Daymond', 'Take Two', 'tvEpisode', 2018),
#  ('Robbie Daymond', 'The Cellar', 'tvEpisode', 2019),
#  ('Robbie Daymond', 'The Hobgoblin: Part One', 'tvEpisode', 2018),
#  ('Robbie Daymond', 'The Hobgoblin: Part Two', 'tvEpisode', 2018),
#  ('Robbie Daymond', 'The Living Brain', 'tvEpisode', 2018),
#  ('Robbie Daymond', 'The Rise of Doc Ock: Part Four', 'tvEpisode', 2018),
#  ('Robbie Daymond', 'The Rise of Doc Ock: Part One', 'tvEpisode', 2018),
#  ('Robbie Daymond', 'The Rise of Doc Ock: Part Three', 'tvEpisode', 2018),
#  ('Robbie Daymond', 'The Rise of Doc Ock: Part Two', 'tvEpisode', 2018),
#  ('Robbie Daymond', 'The Road to Goblin War', 'tvEpisode', 2019),
#  ('Robbie Daymond', 'Ultimate Spider-Man', 'tvEpisode', 2017),
#  ('Robbie Daymond', 'Vengeance of Venom', 'tvEpisode', 2020),
#  ('Robbie Daymond', 'Venom', 'tvEpisode', 2017),
#  ('Robbie Daymond', 'Venom Returns', 'tvEpisode', 2018),
#  ('Robbie Daymond', 'Vibranium Curtain: Part Two', 'tvEpisode', 2019),
#  ('Robbie Daymond', 'Web of Venom', 'tvEpisode', 2020),
#  ('Sean Chiplock', 'The Origin of Spider-Man', 'tvEpisode', 2017),
#  ('Shane Dawson', 'The Lego Batman & Spider-Man Movie 2', 'tvEpisode', 2009),
#  ('Stan Lee', 'Superheroes: A Never-Ending Battle', 'tvMiniSeries', 2013),
#  ('Tobey Maguire', 'Spider-Man', 'movie', 2002),
#  ('Tobey Maguire', 'Spider-Man 2', 'movie', 2004),
#  ('Tobey Maguire', 'Spider-Man 2', 'tvEpisode', 2004),
#  ('Tobey Maguire', 'Spider-Man 3', 'movie', 2007),
#  ('Tobey Maguire', 'Top 11 Dumbasses in Distress', 'tvEpisode', 2011),
#  ('Tom Holland', 'Spider-Man: Far from Home', 'movie', 2019),
#  ('Tom Holland', 'Spider-Man: Homecoming', 'movie', 2017),
#  ('Tom Holland', 'Spider-Man: No Way Home', 'movie', 2021)]

# %%
# %%sql
#
# SELECT Names_.name_, Titles.primary_title, Titles.title_type, Titles.start_year
# FROM Had_role
# INNER JOIN Titles ON Had_role.title_id = Titles.title_id
# INNER JOIN Names_ ON Had_role.name_id = Names_.name_id
# WHERE (Had_role.role_ LIKE "Spider-Man")
# AND (Titles.title_type = "movie")
# ORDER BY Titles.start_year;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 8 rows affected.
# [('Tobey Maguire', 'Spider-Man', 'movie', 2002),
#  ('Tobey Maguire', 'Spider-Man 2', 'movie', 2004),
#  ('Tobey Maguire', 'Spider-Man 3', 'movie', 2007),
#  ('Andrew Garfield', 'The Amazing Spider-Man', 'movie', 2012),
#  ('Andrew Garfield', 'The Amazing Spider-Man 2', 'movie', 2014),
#  ('Tom Holland', 'Spider-Man: Homecoming', 'movie', 2017),
#  ('Tom Holland', 'Spider-Man: Far from Home', 'movie', 2019),
#  ('Tom Holland', 'Spider-Man: No Way Home', 'movie', 2021)]

# %% [markdown]
# #### 3 - List and count the top 10 people who have appeared the most in movies directed by Wes Anderson.

# %%
# %%sql
#
# DESCRIBE Directors;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [('title_id', 'varchar(255)', 'NO', '', None, ''),
#  ('name_id', 'varchar(255)', 'NO', '', None, '')]

# %%
# %%sql
#
# SELECT Names_.name_, Directors.*
# FROM Directors
# INNER JOIN Names_ ON Directors.name_id = Names_.name_id
# WHERE (Names_.name_ LIKE "Wes Anderson")
# Out:
#  * mysql+mysqlconnector://root:***@db
# 10 rows affected.
# [('Wes Anderson', 'tt0115734', 'nm0027572'),
#  ('Wes Anderson', 'tt0128445', 'nm0027572'),
#  ('Wes Anderson', 'tt0265666', 'nm0027572'),
#  ('Wes Anderson', 'tt0362270', 'nm0027572'),
#  ('Wes Anderson', 'tt0432283', 'nm0027572'),
#  ('Wes Anderson', 'tt0838221', 'nm0027572'),
#  ('Wes Anderson', 'tt1748122', 'nm0027572'),
#  ('Wes Anderson', 'tt2278388', 'nm0027572'),
#  ('Wes Anderson', 'tt5104604', 'nm0027572'),
#  ('Wes Anderson', 'tt8847712', 'nm0027572')]

# %%
# %%sql
#
# SELECT Directors.title_id
# FROM Directors
# INNER JOIN Names_ ON Directors.name_id = Names_.name_id
# WHERE (Names_.name_ LIKE "Wes Anderson" );
# Out:
#  * mysql+mysqlconnector://root:***@db
# 10 rows affected.
# [('tt0115734',),
#  ('tt0128445',),
#  ('tt0265666',),
#  ('tt0362270',),
#  ('tt0432283',),
#  ('tt0838221',),
#  ('tt1748122',),
#  ('tt2278388',),
#  ('tt5104604',),
#  ('tt8847712',)]

# %%
# %%sql
#
# SELECT Had_role.name_id
# FROM Had_role
# JOIN Directors ON Had_role.title_id = Directors.title_id
# JOIN Names_ ON Directors.name_id = Names_.name_id
# WHERE Names_.name_ LIKE "Wes Anderson";
# Out:
#  * mysql+mysqlconnector://root:***@db
# 40 rows affected.
# [('nm0005561',),
#  ('nm0005562',),
#  ('nm0235684',),
#  ('nm0288800',),
#  ('nm0005403',),
#  ('nm0000195',),
#  ('nm0931404',),
#  ('nm0001025',),
#  ('nm0000432',),
#  ('nm0000569',),
#  ('nm0001378',),
#  ('nm0001774',),
#  ('nm0000195',),
#  ('nm0005562',),
#  ('nm0001378',),
#  ('nm0000949',),
#  ('nm0000123',),
#  ('nm0000658',),
#  ('nm0000195',),
#  ('nm0005403',),
#  ('nm0005562',),
#  ('nm0004778',),
#  ('nm0005403',),
#  ('nm2496312',),
#  ('nm4442068',),
#  ('nm4442319',),
#  ('nm0000246',),
#  ('nm0000195',),
#  ('nm0000146',),
#  ('nm0000719',),
#  ('nm0023832',),
#  ('nm0004778',),
#  ('nm0186505',),
#  ('nm8659025',),
#  ('nm0001570',),
#  ('nm0000837',),
#  ('nm0001125',),
#  ('nm0004778',),
#  ('nm0842770',),
#  ('nm2244205',)]

# %%
# %%sql
#
# SELECT H.name_id, N.name_
# FROM Had_role H
# INNER JOIN Names_ N ON H.name_id = N.name_id
# WHERE (H.title_id IN (
#     SELECT D.title_id
#     FROM Directors D
#     INNER JOIN Names_ N1 ON D.name_id = N1.name_id
#     WHERE (N1.name_ LIKE "Wes Anderson" )
#     )
# );
# Out:
#  * mysql+mysqlconnector://root:***@db
# 39 rows affected.
# [('nm0000123', 'George Clooney'),
#  ('nm0000146', 'Ralph Fiennes'),
#  ('nm0000195', 'Bill Murray'),
#  ('nm0000195', 'Bill Murray'),
#  ('nm0000195', 'Bill Murray'),
#  ('nm0000195', 'Bill Murray'),
#  ('nm0000246', 'Bruce Willis'),
#  ('nm0000432', 'Gene Hackman'),
#  ('nm0000569', 'Gwyneth Paltrow'),
#  ('nm0000658', 'Meryl Streep'),
#  ('nm0000719', 'F. Murray Abraham'),
#  ('nm0000837', 'Bob Balaban'),
#  ('nm0000949', 'Cate Blanchett'),
#  ('nm0001025', 'Seymour Cassel'),
#  ('nm0001125', 'Benicio Del Toro'),
#  ('nm0001378', 'Anjelica Huston'),
#  ('nm0001378', 'Anjelica Huston'),
#  ('nm0001570', 'Edward Norton'),
#  ('nm0001774', 'Ben Stiller'),
#  ('nm0004778', 'Adrien Brody'),
#  ('nm0004778', 'Adrien Brody'),
#  ('nm0004778', 'Adrien Brody'),
#  ('nm0005403', 'Jason Schwartzman'),
#  ('nm0005403', 'Jason Schwartzman'),
#  ('nm0005403', 'Jason Schwartzman'),
#  ('nm0005561', 'Luke Wilson'),
#  ('nm0005562', 'Owen Wilson'),
#  ('nm0005562', 'Owen Wilson'),
#  ('nm0005562', 'Owen Wilson'),
#  ('nm0023832', 'Mathieu Amalric'),
#  ('nm0186505', 'Bryan Cranston'),
#  ('nm0235684', 'Ned Dowd'),
#  ('nm0288800', 'Shea Fowler'),
#  ('nm0842770', 'Tilda Swinton'),
#  ('nm0931404', 'Olivia Williams'),
#  ('nm2244205', 'Léa Seydoux'),
#  ('nm2496312', 'Amara Karan'),
#  ('nm4442068', 'Jared Gilman'),
#  ('nm4442319', 'Kara Hayward')]

# %%
# %%sql
#
# SELECT N.name_, COUNT(*) AS count
# FROM Had_role H
# INNER JOIN Names_ N ON H.name_id = N.name_id
# WHERE (H.title_id IN (
#     SELECT D.title_id
#     FROM Directors D
#     INNER JOIN Names_ N1 ON D.name_id = N1.name_id
#     WHERE (N1.name_ LIKE "Wes Anderson" )
#     )
# )
# GROUP BY N.name_
# ORDER BY count DESC
# LIMIT 10;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 10 rows affected.
# [('Bill Murray', 4),
#  ('Owen Wilson', 3),
#  ('Jason Schwartzman', 3),
#  ('Adrien Brody', 3),
#  ('Anjelica Huston', 2),
#  ('Ralph Fiennes', 1),
#  ('Kara Hayward', 1),
#  ('Gene Hackman', 1),
#  ('Gwyneth Paltrow', 1),
#  ('F. Murray Abraham', 1)]

# %% [markdown]
# ### Is IMDB only about movies?
# 1. Check the number of different media types contained in the database
# 1. Plot a histogram summarizing the number of titles per media type
# 1. Find the name and rating of the oldest videogame stored in the database

# %% [markdown]
# #### 1 - Check the number of different media types contained in the database

# %%
# %%sql
#
# DESCRIBE Titles;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('title_id', 'varchar(255)', 'NO', '', None, ''),
#  ('title_type', 'varchar(50)', 'YES', '', None, ''),
#  ('primary_title', 'text', 'YES', '', None, ''),
#  ('start_year', 'int', 'YES', '', None, ''),
#  ('runtime_minutes', 'int', 'YES', '', None, '')]

# %%
# %%sql
#
# SELECT DISTINCT title_type
# FROM Titles;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('movie',), ('tvEpisode',), ('tvSeries',), ('tvMiniSeries',), ('videoGame',)]

# %% [markdown]
# #### 2 - Plot a histogram summarizing the number of titles per media type

# %%
res_ = %sql SELECT DISTINCT title_type, COUNT(title_type) AS count FROM Titles GROUP BY title_type ORDER BY count DESC;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.

# %%
res_.bar();

# %% [markdown]
# #### 3 - Find the name and rating of the oldest videogame stored in the database

# %%
# %%sql
#
# DESCRIBE Titles;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('title_id', 'varchar(255)', 'NO', '', None, ''),
#  ('title_type', 'varchar(50)', 'YES', '', None, ''),
#  ('primary_title', 'text', 'YES', '', None, ''),
#  ('start_year', 'int', 'YES', '', None, ''),
#  ('runtime_minutes', 'int', 'YES', '', None, '')]

# %%
# %%sql
#
# SELECT MIN(start_year)
# FROM Titles
# WHERE (title_type = 'videoGame')
# AND (start_year IS NOT NULL);
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [(1990,)]

# %%
# %%sql
#
# SELECT *
# FROM Titles
# WHERE (title_type = 'videoGame')
# AND (start_year IS NOT NULL)
# ORDER BY start_year ASC
# LIMIT 1;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [('tt0154789', 'videoGame', 'Lord of the Rings', 1990, 235)]

# %%
# %%sql
#
# SELECT *
# FROM Titles
# WHERE (title_type = 'videoGame')
# AND (start_year IS NOT NULL)
# ORDER BY start_year ASC
# LIMIT 10;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 10 rows affected.
# [('tt0154789', 'videoGame', 'Lord of the Rings', 1990, 235),
#  ('tt3326048', 'videoGame', 'Four Million Memories: The 1991 Toronto Blue Jays Highlight Video', 1991, 60),
#  ('tt0296852', 'videoGame', 'The Simpsons', 1991, 58),
#  ('tt5435234', 'videoGame', "Girl's Club", 1992, 93),
#  ('tt2912662', 'videoGame', 'BlaZeon', 1992, 38),
#  ('tt2945568', 'videoGame', 'Shogun Warriors', 1992, 101),
#  ('tt6050814', 'videoGame', 'Pacific Islands', 1992, 46),
#  ('tt14856064', 'videoGame', 'Rap Rat', 1992, 56),
#  ('tt6066512', 'videoGame', 'B-17 Flying Fortress', 1992, 53),
#  ('tt9698142', 'videoGame', 'Garth Brooks: We Shall Be Free', 1992, 4)]

# %%
# %%sql
#
# DESCRIBE Title_ratings;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 3 rows affected.
# [('title_id', 'varchar(255)', 'NO', '', None, ''),
#  ('average_rating', 'float', 'YES', '', None, ''),
#  ('num_votes', 'int', 'YES', '', None, '')]

# %%
# %%sql
#
# SELECT *
# FROM Titles
# LEFT JOIN Title_ratings ON Title_ratings.title_id = Titles.title_id
# WHERE (title_type LIKE 'videoGame')
# AND (start_year IS NOT NULL)
# ORDER BY start_year ASC
# LIMIT 10;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 10 rows affected.
# [('tt0154789', 'videoGame', 'Lord of the Rings', 1990, 235, 'tt0154789', 6.9, 162),
#  ('tt3326048', 'videoGame', 'Four Million Memories: The 1991 Toronto Blue Jays Highlight Video', 1991, 60, None, None, None),
#  ('tt0296852', 'videoGame', 'The Simpsons', 1991, 58, 'tt0296852', 8.4, 674),
#  ('tt6050814', 'videoGame', 'Pacific Islands', 1992, 46, None, None, None),
#  ('tt14856064', 'videoGame', 'Rap Rat', 1992, 56, None, None, None),
#  ('tt9698142', 'videoGame', 'Garth Brooks: We Shall Be Free', 1992, 4, None, None, None),
#  ('tt5435234', 'videoGame', "Girl's Club", 1992, 93, None, None, None),
#  ('tt6066512', 'videoGame', 'B-17 Flying Fortress', 1992, 53, None, None, None),
#  ('tt2912662', 'videoGame', 'BlaZeon', 1992, 38, None, None, None),
#  ('tt2945568', 'videoGame', 'Shogun Warriors', 1992, 101, None, None, None)]

# %%
# %%sql
#
# SELECT *
# FROM Titles
# INNER JOIN Title_ratings ON Title_ratings.title_id = Titles.title_id
# WHERE (title_type LIKE 'videoGame')
# AND (start_year IS NOT NULL)
# AND (average_rating IS NOT NULL)
# ORDER BY start_year, primary_title ASC
# LIMIT 10;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 10 rows affected.
# [('tt0154789', 'videoGame', 'Lord of the Rings', 1990, 235, 'tt0154789', 6.9, 162),
#  ('tt0296852', 'videoGame', 'The Simpsons', 1991, 58, 'tt0296852', 8.4, 674),
#  ('tt0400149', 'videoGame', 'Alien Carnage', 1993, 52, 'tt0400149', 6.8, 31),
#  ('tt0462394', 'videoGame', 'Land of Illusion', 1993, 29, 'tt0462394', 7.3, 44),
#  ('tt0445092', 'videoGame', 'Sim City Enhanced CD-ROM', 1993, 20, 'tt0445092', 7.0, 59),
#  ('tt0375096', 'videoGame', 'Star Trek the Next Generation Interactive VHS Board Game', 1993, 60, 'tt0375096', 8.2, 72),
#  ('tt12425372', 'videoGame', 'Crusader of Centy', 1994, 510, 'tt12425372', 8.0, 7),
#  ('tt0113863', 'videoGame', 'Mr. Payback: An Interactive Movie', 1995, 30, 'tt0113863', 4.7, 102),
#  ('tt0114282', 'videoGame', 'Ride for Your Life', 1995, 28, 'tt0114282', 5.9, 22),
#  ('tt0117012', 'videoGame', 'Maximum Surge', 1996, 97, 'tt0117012', 4.1, 24)]

# %% [markdown]
# ### Identify interesting outliers
#
# 1. List the names of all movies whose titles begin with "The" and have a runtime between 3 and 4 hours.
# 2. What actor had the most roles as 'Self'?
# 3. Identify what TV series had more than 1,000 episodes, and identify in what year it was aired the first- and last-episode

# %% [markdown]
# #### 1 - List the names of all movies whose titles begin with "The" and have a runtime between 3 and 4 hours.

# %%
# %%sql
#
# DESCRIBE Titles;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('title_id', 'varchar(255)', 'NO', '', None, ''),
#  ('title_type', 'varchar(50)', 'YES', '', None, ''),
#  ('primary_title', 'text', 'YES', '', None, ''),
#  ('start_year', 'int', 'YES', '', None, ''),
#  ('runtime_minutes', 'int', 'YES', '', None, '')]

# %%
# %%sql
#
# SELECT *
# FROM Titles
# WHERE (title_type LIKE "movie")
# AND (runtime_minutes BETWEEN (2*60) AND (3*60))
# AND (primary_title LIKE "The%s")
# ORDER BY runtime_minutes DESC
# LIMIT 10;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 10 rows affected.
# [('tt0104350', 'movie', 'The Best Intentions', 1992, 180),
#  ('tt7104946', 'movie', 'The Rolling Stones First Fifty Years', 2017, 179),
#  ('tt0167261', 'movie', 'The Lord of the Rings: The Two Towers', 2002, 179),
#  ('tt11463528', 'movie', 'The Extravagant Shadows', 2012, 175),
#  ('tt11777952', 'movie', 'The Exit of the Trains', 2020, 175),
#  ('tt15566782', 'movie', 'The Justice Wars', 2021, 172),
#  ('tt7474934', 'movie', 'The Last Bus', 2017, 172),
#  ('tt7167192', 'movie', 'The Chorus', 2018, 170),
#  ('tt0130748', 'movie', 'The Battle of Canudos', 1997, 170),
#  ('tt0111348', 'movie', 'The Taebaek Mountains', 1994, 168)]

# %% [markdown]
# #### 2 - What actor had the most roles as 'Self'?

# %%
# %%sql
#
# DESCRIBE Had_role;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 3 rows affected.
# [('title_id', 'varchar(255)', 'NO', '', None, ''),
#  ('name_id', 'varchar(255)', 'NO', '', None, ''),
#  ('role_', 'text', 'NO', '', None, '')]

# %%
# %%sql
#
# SELECT name_id, COUNT(name_id) AS count
# FROM Had_role
# WHERE role_ LIKE 'Self'
# GROUP BY name_id
# ORDER BY count DESC
# LIMIT 1;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [('nm9981601', 4835)]

# %%
# %%sql
#
# SELECT Names_.name_, COUNT(Names_.name_) AS count
# FROM Names_
# INNER JOIN Had_role ON Names_.name_id = Had_role.name_id
# WHERE (role_ = "Self")
# GROUP BY Names_.name_
# ORDER BY count DESC
# LIMIT 1;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [('Scott Morrison', 3197)]

# %% [markdown]
# #### 3 - Identify what TV series had more than 1,000 episodes, and identify in what year it was aired the first episode

# %%
# %%sql
#
# DESCRIBE Episode_belongs_to;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [('episode_title_id', 'varchar(255)', 'NO', '', None, ''),
#  ('parent_tv_show_title_id', 'varchar(255)', 'NO', '', None, ''),
#  ('season_number', 'int', 'YES', '', None, ''),
#  ('episode_number', 'int', 'YES', '', None, '')]

# %%
# %%sql
#
# DESCRIBE Titles;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('title_id', 'varchar(255)', 'NO', '', None, ''),
#  ('title_type', 'varchar(50)', 'YES', '', None, ''),
#  ('primary_title', 'text', 'YES', '', None, ''),
#  ('start_year', 'int', 'YES', '', None, ''),
#  ('runtime_minutes', 'int', 'YES', '', None, '')]

# %%
# %%sql
#
# SELECT DISTINCT title_type
# FROM Titles;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('movie',), ('tvEpisode',), ('tvSeries',), ('tvMiniSeries',), ('videoGame',)]

# %%
# %%sql
#
# CREATE VIEW TitleSeries AS
# SELECT *
# FROM Titles
# WHERE Titles.title_type IN ("tvEpisode","tvSeries","tvMiniSeries");
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# SHOW Tables;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 8 rows affected.
# [('Directors',),
#  ('Episode_belongs_to',),
#  ('Had_role',),
#  ('Names_',),
#  ('TitleSeries',),
#  ('Title_genres',),
#  ('Title_ratings',),
#  ('Titles',)]

# %%
# %%sql
#
# SELECT * FROM TitleSeries LIMIT 10;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 10 rows affected.
# [('tt0073481', 'tvEpisode', 'Old Times', 1991, 78),
#  ('tt0080217', 'tvSeries', 'Hana no mahoutsukai Mary Bell', 1992, 24),
#  ('tt0087305', 'tvSeries', 'The Power of Desire', 1999, 45),
#  ('tt0088283', 'tvEpisode', 'Tod durch elektrischen Strom', 1990, 70),
#  ('tt0088472', 'tvSeries', "An Actor's Life for Me", 1991, 30),
#  ('tt0088473', 'tvSeries', 'Adventures in Wonderland', 1992, 30),
#  ('tt0088655', 'tvSeries', 'AD Police Files', 1990, 121),
#  ('tt0088656', 'tvEpisode', 'A.D. Police File 2: The Ripper', 1990, 40),
#  ('tt0088657', 'tvEpisode', 'AD Police Files 3: The Man Who Bites His Tongue', 1990, 40),
#  ('tt0089749', 'tvMiniSeries', 'Otaku no video', 1991, 50)]

# %%
# %%sql
#
# SELECT *
# FROM Episode_belongs_to
# INNER JOIN TitleSeries ON TitleSeries.title_id = Episode_belongs_to.parent_tv_show_title_id
# LIMIT 10;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 10 rows affected.
# [('tt0088656', 'tt0088655', 1, 2, 'tt0088655', 'tvSeries', 'AD Police Files', 1990, 121),
#  ('tt0088657', 'tt0088655', 1, 3, 'tt0088655', 'tvSeries', 'AD Police Files', 1990, 121),
#  ('tt0095671', 'tt0095670', 1, 6, 'tt0095670', 'tvSeries', 'La mujer de tu vida', 1990, 60),
#  ('tt0095672', 'tt0095670', 1, 4, 'tt0095670', 'tvSeries', 'La mujer de tu vida', 1990, 60),
#  ('tt0095673', 'tt0095670', 1, 3, 'tt0095670', 'tvSeries', 'La mujer de tu vida', 1990, 60),
#  ('tt0095674', 'tt0095670', 1, 5, 'tt0095670', 'tvSeries', 'La mujer de tu vida', 1990, 60),
#  ('tt0097451', 'tt0099283', 1, 6, 'tt0099283', 'tvSeries', 'Le gorille', 1990, 92),
#  ('tt0097924', 'tt0095670', 1, 7, 'tt0095670', 'tvSeries', 'La mujer de tu vida', 1990, 60),
#  ('tt0097925', 'tt0095670', 1, 2, 'tt0095670', 'tvSeries', 'La mujer de tu vida', 1990, 60),
#  ('tt0099217', 'tt0098761', 1, 1, 'tt0098761', 'tvSeries', 'Capital News', 1990, 60)]

# %%
# %%sql
#
# CREATE VIEW MoreThan1KEpisodes AS
# SELECT parent_tv_show_title_id, COUNT(episode_title_id) AS nEpisodes
# FROM Episode_belongs_to
# GROUP BY parent_tv_show_title_id
# HAVING nEpisodes > 1000;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# SELECT *
# FROM MoreThan1KEpisodes
# LIMIT 10;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 10 rows affected.
# [('tt0112004', 4367),
#  ('tt0296318', 1366),
#  ('tt0305056', 3408),
#  ('tt0167515', 3748),
#  ('tt0122335', 1207),
#  ('tt0472642', 2223),
#  ('tt0380086', 2775),
#  ('tt0374364', 3885),
#  ('tt0439344', 2807),
#  ('tt0386155', 2515)]

# %%
# %%sql
#
# SELECT *
# FROM MoreThan1KEpisodes
# INNER JOIN TitleSeries ON TitleSeries.title_id = MoreThan1KEpisodes.parent_tv_show_title_id
# ORDER BY nEpisodes DESC
# LIMIT 10;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 10 rows affected.
# [('tt0270116', 9884, 'tt0270116', 'tvSeries', 'Charlie Rose', 1991, 60),
#  ('tt0103434', 7455, 'tt0103434', 'tvSeries', 'Gute Zeiten, schlechte Zeiten', 1992, 25),
#  ('tt0115227', 7282, 'tt0115227', 'tvSeries', 'Judge Judy', 1996, 30),
#  ('tt0108977', 6803, 'tt0108977', 'tvSeries', 'Unter uns', 1994, 25),
#  ('tt0106053', 6691, 'tt0106053', 'tvSeries', 'Late Show with David Letterman', 1993, 60),
#  ('tt0096597', 6550, 'tt0096597', 'tvSeries', 'Goede tijden, slechte tijden', 1990, 23),
#  ('tt0144724', 6247, 'tt0144724', 'tvSeries', 'Young Hearts', 1995, 30),
#  ('tt0289801', 5433, 'tt0289801', 'tvSeries', 'DAS!', 1991, 45),
#  ('tt4816922', 5273, 'tt4816922', 'tvSeries', "L'invité", 2000, 8),
#  ('tt0498891', 5111, 'tt0498891', 'tvSeries', 'Volle Kanne', 1999, 85)]

# %% [markdown]
# ### It's all about the ratings
#
# 1. Group all movies by decade and plot their overall rating distribution trend. Limit the query to the movies with at least 1000 ratings.
# 2. Plot the average rating of each episode of "Games of Thrones". Group by season and compute the average and standard deviation for each season
# 3. Plot the total number of movies produced per year, divided by genre (Action, Comedy, Drama, Thriller, Fantasy), and the yearly rating average per genre

# %% [markdown]
# #### 1 - Group all movies by decade and plot their overall rating distribution trend. Limit the query to the movies with at least 1000 ratings.

# %%
# %%sql
#
# DESCRIBE Titles
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('title_id', 'varchar(255)', 'NO', '', None, ''),
#  ('title_type', 'varchar(50)', 'YES', '', None, ''),
#  ('primary_title', 'text', 'YES', '', None, ''),
#  ('start_year', 'int', 'YES', '', None, ''),
#  ('runtime_minutes', 'int', 'YES', '', None, '')]

# %%
# %%sql
#
# DESCRIBE Title_ratings
# Out:
#  * mysql+mysqlconnector://root:***@db
# 3 rows affected.
# [('title_id', 'varchar(255)', 'NO', '', None, ''),
#  ('average_rating', 'float', 'YES', '', None, ''),
#  ('num_votes', 'int', 'YES', '', None, '')]

# %%
# %%sql res_ << SELECT FLOOR(T.start_year / 10) * 10 AS decade, AVG(R.average_rating) as avgRateDecade
# FROM Titles T
# INNER JOIN Title_ratings R ON R.title_id = T.title_id
# WHERE T.title_type = "movie"
# AND T.start_year IS NOT NULL
# AND R.num_votes >= 1000
# GROUP BY decade
# ORDER BY decade ASC
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# Returning data to local variable res_

# %%
res_.plot();

# %% [markdown]
# #### 2 - Plot the average rating of each episode of "Games of Thrones". Group by season and compute the average and standard deviation for each season.

# %%
# %%sql
#
# DESCRIBE Episode_belongs_to;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [('episode_title_id', 'varchar(255)', 'NO', '', None, ''),
#  ('parent_tv_show_title_id', 'varchar(255)', 'NO', '', None, ''),
#  ('season_number', 'int', 'YES', '', None, ''),
#  ('episode_number', 'int', 'YES', '', None, '')]

# %%
# %%sql
#
# DESCRIBE Title_ratings;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 3 rows affected.
# [('title_id', 'varchar(255)', 'NO', '', None, ''),
#  ('average_rating', 'float', 'YES', '', None, ''),
#  ('num_votes', 'int', 'YES', '', None, '')]

# %%
# %%sql
#
# SELECT title_id
# FROM Titles
# WHERE primary_title = 'Game of Thrones'
# AND title_type = 'tvSeries';
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [('tt0944947',)]

# %%
# %%sql
#
# SELECT *
# FROM Episode_belongs_to E
# INNER JOIN Titles T ON E.parent_tv_show_title_id = T.title_id
# WHERE T.primary_title = 'Game of Thrones'
# AND T.title_type = 'tvSeries'
# ORDER BY E.season_number, E.episode_number;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 73 rows affected.
# [('tt1480055', 'tt0944947', 1, 1, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt1668746', 'tt0944947', 1, 2, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt1829962', 'tt0944947', 1, 3, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt1829963', 'tt0944947', 1, 4, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt1829964', 'tt0944947', 1, 5, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt1837862', 'tt0944947', 1, 6, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt1837863', 'tt0944947', 1, 7, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt1837864', 'tt0944947', 1, 8, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt1851398', 'tt0944947', 1, 9, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt1851397', 'tt0944947', 1, 10, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt1971833', 'tt0944947', 2, 1, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt2069318', 'tt0944947', 2, 2, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt2070135', 'tt0944947', 2, 3, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt2069319', 'tt0944947', 2, 4, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt2074658', 'tt0944947', 2, 5, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt2085238', 'tt0944947', 2, 6, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt2085239', 'tt0944947', 2, 7, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt2085240', 'tt0944947', 2, 8, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt2084342', 'tt0944947', 2, 9, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt2112510', 'tt0944947', 2, 10, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt2178782', 'tt0944947', 3, 1, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt2178772', 'tt0944947', 3, 2, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt2178802', 'tt0944947', 3, 3, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt2178798', 'tt0944947', 3, 4, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt2178788', 'tt0944947', 3, 5, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt2178812', 'tt0944947', 3, 6, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt2178814', 'tt0944947', 3, 7, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt2178806', 'tt0944947', 3, 8, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt2178784', 'tt0944947', 3, 9, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt2178796', 'tt0944947', 3, 10, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt2816136', 'tt0944947', 4, 1, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt2832378', 'tt0944947', 4, 2, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt2972426', 'tt0944947', 4, 3, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt2972428', 'tt0944947', 4, 4, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt3060856', 'tt0944947', 4, 5, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt3060910', 'tt0944947', 4, 6, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt3060876', 'tt0944947', 4, 7, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt3060782', 'tt0944947', 4, 8, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt3060858', 'tt0944947', 4, 9, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt3060860', 'tt0944947', 4, 10, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt3658012', 'tt0944947', 5, 1, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt3846626', 'tt0944947', 5, 2, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt3866836', 'tt0944947', 5, 3, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt3866838', 'tt0944947', 5, 4, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt3866840', 'tt0944947', 5, 5, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt3866842', 'tt0944947', 5, 6, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt3866846', 'tt0944947', 5, 7, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt3866850', 'tt0944947', 5, 8, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt3866826', 'tt0944947', 5, 9, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt3866862', 'tt0944947', 5, 10, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt3658014', 'tt0944947', 6, 1, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt4077554', 'tt0944947', 6, 2, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt4131606', 'tt0944947', 6, 3, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt4283016', 'tt0944947', 6, 4, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt4283028', 'tt0944947', 6, 5, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt4283054', 'tt0944947', 6, 6, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt4283060', 'tt0944947', 6, 7, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt4283074', 'tt0944947', 6, 8, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt4283088', 'tt0944947', 6, 9, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt4283094', 'tt0944947', 6, 10, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt5654088', 'tt0944947', 7, 1, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt5655178', 'tt0944947', 7, 2, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt5775840', 'tt0944947', 7, 3, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt5775846', 'tt0944947', 7, 4, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt5775854', 'tt0944947', 7, 5, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt5775864', 'tt0944947', 7, 6, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt5775874', 'tt0944947', 7, 7, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt5924366', 'tt0944947', 8, 1, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt6027908', 'tt0944947', 8, 2, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt6027912', 'tt0944947', 8, 3, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt6027914', 'tt0944947', 8, 4, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt6027916', 'tt0944947', 8, 5, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57),
#  ('tt6027920', 'tt0944947', 8, 6, 'tt0944947', 'tvSeries', 'Game of Thrones', 2011, 57)]

# %%
# %%sql
#
# SELECT T.primary_title, E.season_number, E.episode_number, R.average_rating
# FROM Episode_belongs_to E
# INNER JOIN Titles T ON T.title_id = E.episode_title_id
# INNER JOIN Title_ratings R ON R.title_id = E.episode_title_id
# INNER JOIN Titles P ON E.parent_tv_show_title_id = P.title_id
# WHERE P.primary_title = 'Game of Thrones'
# AND P.title_type = 'tvSeries'
# ORDER BY E.season_number, E.episode_number;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 73 rows affected.
# [('Winter Is Coming', 1, 1, 9.1),
#  ('The Kingsroad', 1, 2, 8.8),
#  ('Lord Snow', 1, 3, 8.7),
#  ('Cripples, Bastards, and Broken Things', 1, 4, 8.8),
#  ('The Wolf and the Lion', 1, 5, 9.1),
#  ('A Golden Crown', 1, 6, 9.2),
#  ('You Win or You Die', 1, 7, 9.2),
#  ('The Pointy End', 1, 8, 9.0),
#  ('Baelor', 1, 9, 9.6),
#  ('Fire and Blood', 1, 10, 9.5),
#  ('The North Remembers', 2, 1, 8.8),
#  ('The Night Lands', 2, 2, 8.5),
#  ('What Is Dead May Never Die', 2, 3, 8.8),
#  ('Garden of Bones', 2, 4, 8.8),
#  ('The Ghost of Harrenhal', 2, 5, 8.8),
#  ('The Old Gods and the New', 2, 6, 9.1),
#  ('A Man Without Honor', 2, 7, 8.9),
#  ('The Prince of Winterfell', 2, 8, 8.8),
#  ('Blackwater', 2, 9, 9.7),
#  ('Valar Morghulis', 2, 10, 9.4),
#  ('Valar Dohaeris', 3, 1, 8.8),
#  ('Dark Wings, Dark Words', 3, 2, 8.6),
#  ('Walk of Punishment', 3, 3, 8.9),
#  ('And Now His Watch Is Ended', 3, 4, 9.6),
#  ('Kissed by Fire', 3, 5, 9.0),
#  ('The Climb', 3, 6, 8.8),
#  ('The Bear and the Maiden Fair', 3, 7, 8.7),
#  ('Second Sons', 3, 8, 9.0),
#  ('The Rains of Castamere', 3, 9, 9.9),
#  ('Mhysa', 3, 10, 9.2),
#  ('Two Swords', 4, 1, 9.1),
#  ('The Lion and the Rose', 4, 2, 9.7),
#  ('Breaker of Chains', 4, 3, 8.9),
#  ('Oathkeeper', 4, 4, 8.8),
#  ('First of His Name', 4, 5, 8.8),
#  ('The Laws of Gods and Men', 4, 6, 9.7),
#  ('Mockingbird', 4, 7, 9.1),
#  ('The Mountain and the Viper', 4, 8, 9.7),
#  ('The Watchers on the Wall', 4, 9, 9.6),
#  ('The Children', 4, 10, 9.7),
#  ('The Wars to Come', 5, 1, 8.5),
#  ('The House of Black and White', 5, 2, 8.5),
#  ('High Sparrow', 5, 3, 8.5),
#  ('Sons of the Harpy', 5, 4, 8.7),
#  ('Kill the Boy', 5, 5, 8.6),
#  ('Unbowed, Unbent, Unbroken', 5, 6, 8.0),
#  ('The Gift', 5, 7, 9.0),
#  ('Hardhome', 5, 8, 9.9),
#  ('The Dance of Dragons', 5, 9, 9.5),
#  ("Mother's Mercy", 5, 10, 9.1),
#  ('The Red Woman', 6, 1, 8.5),
#  ('Home', 6, 2, 9.4),
#  ('Oathbreaker', 6, 3, 8.7),
#  ('Book of the Stranger', 6, 4, 9.1),
#  ('The Door', 6, 5, 9.7),
#  ('Blood of My Blood', 6, 6, 8.4),
#  ('The Broken Man', 6, 7, 8.6),
#  ('No One', 6, 8, 8.4),
#  ('Battle of the Bastards', 6, 9, 9.9),
#  ('The Winds of Winter', 6, 10, 9.9),
#  ('Dragonstone', 7, 1, 8.6),
#  ('Stormborn', 7, 2, 8.9),
#  ("The Queen's Justice", 7, 3, 9.2),
#  ('The Spoils of War', 7, 4, 9.8),
#  ('Eastwatch', 7, 5, 8.8),
#  ('Beyond the Wall', 7, 6, 9.0),
#  ('The Dragon and the Wolf', 7, 7, 9.4),
#  ('Winterfell', 8, 1, 7.5),
#  ('A Knight of the Seven Kingdoms', 8, 2, 7.8),
#  ('The Long Night', 8, 3, 7.4),
#  ('The Last of the Starks', 8, 4, 5.4),
#  ('The Bells', 8, 5, 5.9),
#  ('The Iron Throne', 8, 6, 4.0)]

# %%
dbc.execute("USE IMDb;")

sql_ = """SELECT T.primary_title, E.season_number, E.episode_number, R.average_rating
FROM Episode_belongs_to E
INNER JOIN Titles T ON T.title_id = E.episode_title_id
INNER JOIN Title_ratings R ON R.title_id = E.episode_title_id
INNER JOIN Titles P ON E.parent_tv_show_title_id = P.title_id
WHERE P.primary_title = 'Game of Thrones'
AND P.title_type = 'tvSeries'
ORDER BY E.season_number, E.episode_number;"""

import itertools
dbc.execute(sql_)
res_ = dbc.fetchall()

# %%
seas_ = list(list(zip(*res_))[1])
eos_ = [i for i,x in enumerate(seas_) if seas_[i]-seas_[i-1]==1]

# %%
plt.plot(list(zip(*res_))[3]);
for _ in eos_:
    plt.vlines(_, 
               ymin=0, 
               ymax=10,
               color='orange',
               linestyle=':')
plt.ylabel('episode rating')
plt.xlabel('episode')
# Out:
# Text(0.5, 0, 'episode')

# %% [markdown]
# #### 3 - Plot the total number of movies produced per year, divided by genre (Action, Comedy, Drama, Thriller, Fantasy), and the yearly rating average per genre

# %%
# %%sql
#
# USE IMDb;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# DESCRIBE Title_genres;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [('title_id', 'varchar(255)', 'NO', '', None, ''),
#  ('genre', 'varchar(255)', 'NO', '', None, '')]

# %%
# %%sql
#
# SELECT DISTINCT genre
# FROM Title_genres;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 25 rows affected.
# [('Drama',),
#  ('Mystery',),
#  ('Romance',),
#  ('Comedy',),
#  ('Fantasy',),
#  ('Documentary',),
#  ('Sport',),
#  ('Action',),
#  ('War',),
#  ('Adventure',),
#  ('Animation',),
#  ('Crime',),
#  ('Family',),
#  ('Biography',),
#  ('History',),
#  ('Music',),
#  ('Sci-Fi',),
#  ('Horror',),
#  ('Musical',),
#  ('News',),
#  ('Thriller',),
#  ('Talk-Show',),
#  ('Game-Show',),
#  ('Western',),
#  ('Short',)]

# %%
# %%sql
#
# SELECT T.start_year, G.genre, COUNT(G.genre), AVG(R.average_rating)
# FROM Title_ratings R
# INNER JOIN Titles T ON T.title_id = R.title_id
# INNER JOIN Title_genres G ON G.title_id = R.title_id
# WHERE T.title_type = 'movie'
# AND T.start_year IS NOT NULL
# AND G.genre IN ('Action', 'Comedy', 'Drama', 'Thriller', 'Fantasy')
# GROUP BY T.start_year, G.genre
# ORDER BY T.start_year, G.genre;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 165 rows affected.
# [(1990, 'Action', 385, 5.513246741232934),
#  (1990, 'Comedy', 550, 5.837272716435519),
#  (1990, 'Drama', 975, 6.179179479770172),
#  (1990, 'Fantasy', 96, 5.828124990065892),
#  (1990, 'Thriller', 189, 5.478306881334416),
#  (1991, 'Action', 348, 5.474999997122534),
#  (1991, 'Comedy', 563, 5.90976910142238),
#  (1991, 'Drama', 1016, 6.194586609761546),
#  (1991, 'Fantasy', 113, 5.744247797316155),
#  (1991, 'Thriller', 169, 5.39881656579012),
#  (1992, 'Action', 331, 5.545317216942317),
#  (1992, 'Comedy', 568, 5.80211268281433),
#  (1992, 'Drama', 926, 6.215118798014927),
#  (1992, 'Fantasy', 78, 6.0487179695031585),
#  (1992, 'Thriller', 195, 5.538974356039977),
#  (1993, 'Action', 338, 5.5254437732978685),
#  (1993, 'Comedy', 518, 5.822007720534866),
#  (1993, 'Drama', 963, 6.143302177466831),
#  (1993, 'Fantasy', 86, 5.93604650331098),
#  (1993, 'Thriller', 225, 5.401333321465386),
#  (1994, 'Action', 332, 5.397891570645642),
#  (1994, 'Comedy', 597, 5.831993293722271),
#  (1994, 'Drama', 1025, 6.146829273875166),
#  (1994, 'Fantasy', 86, 5.732558139534884),
#  (1994, 'Thriller', 225, 5.297333324220445),
#  (1995, 'Action', 349, 5.438968480145692),
#  (1995, 'Comedy', 527, 5.877419359769948),
#  (1995, 'Drama', 1038, 6.11608863807138),
#  (1995, 'Fantasy', 76, 5.964473699268542),
#  (1995, 'Thriller', 252, 5.385317475076706),
#  (1996, 'Action', 303, 5.374917483565831),
#  (1996, 'Comedy', 622, 5.8800643090266504),
#  (1996, 'Drama', 1053, 6.187179493655053),
#  (1996, 'Fantasy', 83, 5.842168695955391),
#  (1996, 'Thriller', 244, 5.3475409824340066),
#  (1997, 'Action', 306, 5.441830067073598),
#  (1997, 'Comedy', 695, 5.846187050737066),
#  (1997, 'Drama', 1119, 6.189901691552675),
#  (1997, 'Fantasy', 73, 5.730136969318129),
#  (1997, 'Thriller', 253, 5.423320160552918),
#  (1998, 'Action', 298, 5.4315436206408),
#  (1998, 'Comedy', 723, 5.860995849633118),
#  (1998, 'Drama', 1169, 6.195551758652778),
#  (1998, 'Fantasy', 78, 5.607692299745022),
#  (1998, 'Thriller', 244, 5.50491803102806),
#  (1999, 'Action', 299, 5.514715712206021),
#  (1999, 'Comedy', 793, 5.831147534549612),
#  (1999, 'Drama', 1279, 6.17865519769682),
#  (1999, 'Fantasy', 86, 5.462790691575338),
#  (1999, 'Thriller', 286, 5.574825160153262),
#  (2000, 'Action', 300, 5.404999989271164),
#  (2000, 'Comedy', 777, 5.846718145460082),
#  (2000, 'Drama', 1353, 6.133628970063006),
#  (2000, 'Fantasy', 97, 5.687628851723425),
#  (2000, 'Thriller', 287, 5.422996515181007),
#  (2001, 'Action', 361, 5.557894745031552),
#  (2001, 'Comedy', 849, 5.95877503267587),
#  (2001, 'Drama', 1470, 6.211360545061073),
#  (2001, 'Fantasy', 109, 5.762385357410536),
#  (2001, 'Thriller', 278, 5.341007194930701),
#  (2002, 'Action', 367, 5.615531334760079),
#  (2002, 'Comedy', 868, 5.906336409155674),
#  (2002, 'Drama', 1544, 6.189961142413357),
#  (2002, 'Fantasy', 107, 5.790654198031559),
#  (2002, 'Thriller', 260, 5.541153850005223),
#  (2003, 'Action', 351, 5.543874645844484),
#  (2003, 'Comedy', 990, 5.9208080798688565),
#  (2003, 'Drama', 1568, 6.174744892409262),
#  (2003, 'Fantasy', 106, 5.813207557741201),
#  (2003, 'Thriller', 278, 5.465107896345125),
#  (2004, 'Action', 385, 5.595324677306336),
#  (2004, 'Comedy', 992, 5.896774194533786),
#  (2004, 'Drama', 1680, 6.229999997786114),
#  (2004, 'Fantasy', 99, 5.6323232530343414),
#  (2004, 'Thriller', 314, 5.581210181211969),
#  (2005, 'Action', 376, 5.532712771537456),
#  (2005, 'Comedy', 1088, 5.892647058757789),
#  (2005, 'Drama', 1862, 6.237593989111043),
#  (2005, 'Fantasy', 127, 5.6685039396361105),
#  (2005, 'Thriller', 318, 5.571383639326635),
#  (2006, 'Action', 392, 5.492602026280092),
#  (2006, 'Comedy', 1209, 5.826881719877939),
#  (2006, 'Drama', 2053, 6.221773013044321),
#  (2006, 'Fantasy', 153, 5.758823525671866),
#  (2006, 'Thriller', 420, 5.40119046483721),
#  (2007, 'Action', 424, 5.603301888648069),
#  (2007, 'Comedy', 1168, 5.867465756017051),
#  (2007, 'Drama', 2112, 6.221638258772366),
#  (2007, 'Fantasy', 137, 5.663503652071431),
#  (2007, 'Thriller', 438, 5.536757979490986),
#  (2008, 'Action', 468, 5.504059836650506),
#  (2008, 'Comedy', 1320, 5.731136368440859),
#  (2008, 'Drama', 2345, 6.16162046654138),
#  (2008, 'Fantasy', 154, 5.662986999982364),
#  (2008, 'Thriller', 487, 5.499178642120205),
#  (2009, 'Action', 588, 5.541836726827686),
#  (2009, 'Comedy', 1485, 5.845185190178328),
#  (2009, 'Drama', 2671, 6.17529015704426),
#  (2009, 'Fantasy', 190, 5.791052629445728),
#  (2009, 'Thriller', 581, 5.428227200770747),
#  (2010, 'Action', 674, 5.643768554448374),
#  (2010, 'Comedy', 1536, 5.91881510692959),
#  (2010, 'Drama', 2851, 6.236162752655254),
#  (2010, 'Fantasy', 191, 5.798952884074905),
#  (2010, 'Thriller', 645, 5.3987596872241),
#  (2011, 'Action', 673, 5.715453189514013),
#  (2011, 'Comedy', 1663, 5.877811181638446),
#  (2011, 'Drama', 3036, 6.248649541372053),
#  (2011, 'Fantasy', 236, 5.810169495768466),
#  (2011, 'Thriller', 666, 5.507957957707368),
#  (2012, 'Action', 666, 5.736036033243747),
#  (2012, 'Comedy', 1774, 5.896899664617042),
#  (2012, 'Drama', 3126, 6.312092130335187),
#  (2012, 'Fantasy', 212, 6.035377359615182),
#  (2012, 'Thriller', 765, 5.500784315003289),
#  (2013, 'Action', 719, 5.655354663460245),
#  (2013, 'Comedy', 1859, 5.954276500497215),
#  (2013, 'Drama', 3510, 6.3232193772609415),
#  (2013, 'Fantasy', 227, 5.725550667304825),
#  (2013, 'Thriller', 935, 5.457540105753404),
#  (2014, 'Action', 776, 5.757345371639605),
#  (2014, 'Comedy', 1970, 5.935329951066051),
#  (2014, 'Drama', 3580, 6.331424588164804),
#  (2014, 'Fantasy', 253, 5.689328060790955),
#  (2014, 'Thriller', 968, 5.5154958710936475),
#  (2015, 'Action', 803, 5.669987545660691),
#  (2015, 'Comedy', 1937, 5.896644297862213),
#  (2015, 'Drama', 3715, 6.277146705932926),
#  (2015, 'Fantasy', 266, 5.850751876831055),
#  (2015, 'Thriller', 993, 5.493756300132921),
#  (2016, 'Action', 884, 5.677828057589035),
#  (2016, 'Comedy', 2019, 5.837543341946992),
#  (2016, 'Drama', 3687, 6.256034720839605),
#  (2016, 'Fantasy', 294, 5.747959191296377),
#  (2016, 'Thriller', 1001, 5.408891105866218),
#  (2017, 'Action', 888, 5.750337846778534),
#  (2017, 'Comedy', 2004, 5.871407184712663),
#  (2017, 'Drama', 3790, 6.284485487258529),
#  (2017, 'Fantasy', 289, 5.860553635032944),
#  (2017, 'Thriller', 1006, 5.388270375150335),
#  (2018, 'Action', 837, 5.64659497344793),
#  (2018, 'Comedy', 2055, 5.742530414541853),
#  (2018, 'Drama', 3768, 6.207457535522505),
#  (2018, 'Fantasy', 317, 5.811671938053817),
#  (2018, 'Thriller', 1003, 5.413359917410587),
#  (2019, 'Action', 839, 5.683194271429787),
#  (2019, 'Comedy', 1896, 5.812763718047223),
#  (2019, 'Drama', 3754, 6.185695262779628),
#  (2019, 'Fantasy', 262, 5.647709936586045),
#  (2019, 'Thriller', 995, 5.364623119962874),
#  (2020, 'Action', 500, 5.555799997568131),
#  (2020, 'Comedy', 1309, 5.787624140201041),
#  (2020, 'Drama', 2622, 6.141151793761439),
#  (2020, 'Fantasy', 240, 5.749166665971279),
#  (2020, 'Thriller', 795, 5.283270441960989),
#  (2021, 'Action', 604, 5.76076158091722),
#  (2021, 'Comedy', 1206, 6.053482585779668),
#  (2021, 'Drama', 2466, 6.418248176333001),
#  (2021, 'Fantasy', 186, 6.0994623720005),
#  (2021, 'Thriller', 804, 5.716417916230301),
#  (2022, 'Action', 48, 6.512499983112018),
#  (2022, 'Comedy', 129, 6.273643408634866),
#  (2022, 'Drama', 200, 6.9260000026226045),
#  (2022, 'Fantasy', 13, 5.861538428526658),
#  (2022, 'Thriller', 89, 6.451685412546222)]

# %%
dbc.execute("USE IMDb;")

sql_ = """SELECT T.start_year, G.genre, COUNT(G.genre), AVG(R.average_rating)
FROM Title_ratings R
INNER JOIN Titles T ON T.title_id = R.title_id
INNER JOIN Title_genres G ON G.title_id = R.title_id
WHERE T.title_type = 'movie'
AND T.start_year IS NOT NULL
AND G.genre IN ('Action', 'Comedy', 'Drama', 'Thriller', 'Fantasy')
GROUP BY T.start_year, G.genre
ORDER BY T.start_year, G.genre;"""

import itertools
dbc.execute(sql_)
res_ = dbc.fetchall()

# %%
# %%sql re_ << SELECT T.start_year, G.genre, COUNT(G.genre) AS nPerGenre, AVG(R.average_rating) ratPerGenre
# FROM Title_ratings R
# INNER JOIN Titles T ON T.title_id = R.title_id
# INNER JOIN Title_genres G ON G.title_id = R.title_id
# WHERE T.title_type = 'movie'
# AND T.start_year IS NOT NULL
# AND G.genre IN ('Action', 'Comedy', 'Drama', 'Thriller', 'Fantasy')
# GROUP BY T.start_year, G.genre
# ORDER BY T.start_year, G.genre;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 165 rows affected.
# Returning data to local variable re_

# %%
re_
# Out:
# [(1990, 'Action', 385, 5.513246741232934),
#  (1990, 'Comedy', 550, 5.837272716435519),
#  (1990, 'Drama', 975, 6.179179479770172),
#  (1990, 'Fantasy', 96, 5.828124990065892),
#  (1990, 'Thriller', 189, 5.478306881334416),
#  (1991, 'Action', 348, 5.474999997122534),
#  (1991, 'Comedy', 563, 5.90976910142238),
#  (1991, 'Drama', 1016, 6.194586609761546),
#  (1991, 'Fantasy', 113, 5.744247797316155),
#  (1991, 'Thriller', 169, 5.39881656579012),
#  (1992, 'Action', 331, 5.545317216942317),
#  (1992, 'Comedy', 568, 5.80211268281433),
#  (1992, 'Drama', 926, 6.215118798014927),
#  (1992, 'Fantasy', 78, 6.0487179695031585),
#  (1992, 'Thriller', 195, 5.538974356039977),
#  (1993, 'Action', 338, 5.5254437732978685),
#  (1993, 'Comedy', 518, 5.822007720534866),
#  (1993, 'Drama', 963, 6.143302177466831),
#  (1993, 'Fantasy', 86, 5.93604650331098),
#  (1993, 'Thriller', 225, 5.401333321465386),
#  (1994, 'Action', 332, 5.397891570645642),
#  (1994, 'Comedy', 597, 5.831993293722271),
#  (1994, 'Drama', 1025, 6.146829273875166),
#  (1994, 'Fantasy', 86, 5.732558139534884),
#  (1994, 'Thriller', 225, 5.297333324220445),
#  (1995, 'Action', 349, 5.438968480145692),
#  (1995, 'Comedy', 527, 5.877419359769948),
#  (1995, 'Drama', 1038, 6.11608863807138),
#  (1995, 'Fantasy', 76, 5.964473699268542),
#  (1995, 'Thriller', 252, 5.385317475076706),
#  (1996, 'Action', 303, 5.374917483565831),
#  (1996, 'Comedy', 622, 5.8800643090266504),
#  (1996, 'Drama', 1053, 6.187179493655053),
#  (1996, 'Fantasy', 83, 5.842168695955391),
#  (1996, 'Thriller', 244, 5.3475409824340066),
#  (1997, 'Action', 306, 5.441830067073598),
#  (1997, 'Comedy', 695, 5.846187050737066),
#  (1997, 'Drama', 1119, 6.189901691552675),
#  (1997, 'Fantasy', 73, 5.730136969318129),
#  (1997, 'Thriller', 253, 5.423320160552918),
#  (1998, 'Action', 298, 5.4315436206408),
#  (1998, 'Comedy', 723, 5.860995849633118),
#  (1998, 'Drama', 1169, 6.195551758652778),
#  (1998, 'Fantasy', 78, 5.607692299745022),
#  (1998, 'Thriller', 244, 5.50491803102806),
#  (1999, 'Action', 299, 5.514715712206021),
#  (1999, 'Comedy', 793, 5.831147534549612),
#  (1999, 'Drama', 1279, 6.17865519769682),
#  (1999, 'Fantasy', 86, 5.462790691575338),
#  (1999, 'Thriller', 286, 5.574825160153262),
#  (2000, 'Action', 300, 5.404999989271164),
#  (2000, 'Comedy', 777, 5.846718145460082),
#  (2000, 'Drama', 1353, 6.133628970063006),
#  (2000, 'Fantasy', 97, 5.687628851723425),
#  (2000, 'Thriller', 287, 5.422996515181007),
#  (2001, 'Action', 361, 5.557894745031552),
#  (2001, 'Comedy', 849, 5.95877503267587),
#  (2001, 'Drama', 1470, 6.211360545061073),
#  (2001, 'Fantasy', 109, 5.762385357410536),
#  (2001, 'Thriller', 278, 5.341007194930701),
#  (2002, 'Action', 367, 5.615531334760079),
#  (2002, 'Comedy', 868, 5.906336409155674),
#  (2002, 'Drama', 1544, 6.189961142413357),
#  (2002, 'Fantasy', 107, 5.790654198031559),
#  (2002, 'Thriller', 260, 5.541153850005223),
#  (2003, 'Action', 351, 5.543874645844484),
#  (2003, 'Comedy', 990, 5.9208080798688565),
#  (2003, 'Drama', 1568, 6.174744892409262),
#  (2003, 'Fantasy', 106, 5.813207557741201),
#  (2003, 'Thriller', 278, 5.465107896345125),
#  (2004, 'Action', 385, 5.595324677306336),
#  (2004, 'Comedy', 992, 5.896774194533786),
#  (2004, 'Drama', 1680, 6.229999997786114),
#  (2004, 'Fantasy', 99, 5.6323232530343414),
#  (2004, 'Thriller', 314, 5.581210181211969),
#  (2005, 'Action', 376, 5.532712771537456),
#  (2005, 'Comedy', 1088, 5.892647058757789),
#  (2005, 'Drama', 1862, 6.237593989111043),
#  (2005, 'Fantasy', 127, 5.6685039396361105),
#  (2005, 'Thriller', 318, 5.571383639326635),
#  (2006, 'Action', 392, 5.492602026280092),
#  (2006, 'Comedy', 1209, 5.826881719877939),
#  (2006, 'Drama', 2053, 6.221773013044321),
#  (2006, 'Fantasy', 153, 5.758823525671866),
#  (2006, 'Thriller', 420, 5.40119046483721),
#  (2007, 'Action', 424, 5.603301888648069),
#  (2007, 'Comedy', 1168, 5.867465756017051),
#  (2007, 'Drama', 2112, 6.221638258772366),
#  (2007, 'Fantasy', 137, 5.663503652071431),
#  (2007, 'Thriller', 438, 5.536757979490986),
#  (2008, 'Action', 468, 5.504059836650506),
#  (2008, 'Comedy', 1320, 5.731136368440859),
#  (2008, 'Drama', 2345, 6.16162046654138),
#  (2008, 'Fantasy', 154, 5.662986999982364),
#  (2008, 'Thriller', 487, 5.499178642120205),
#  (2009, 'Action', 588, 5.541836726827686),
#  (2009, 'Comedy', 1485, 5.845185190178328),
#  (2009, 'Drama', 2671, 6.17529015704426),
#  (2009, 'Fantasy', 190, 5.791052629445728),
#  (2009, 'Thriller', 581, 5.428227200770747),
#  (2010, 'Action', 674, 5.643768554448374),
#  (2010, 'Comedy', 1536, 5.91881510692959),
#  (2010, 'Drama', 2851, 6.236162752655254),
#  (2010, 'Fantasy', 191, 5.798952884074905),
#  (2010, 'Thriller', 645, 5.3987596872241),
#  (2011, 'Action', 673, 5.715453189514013),
#  (2011, 'Comedy', 1663, 5.877811181638446),
#  (2011, 'Drama', 3036, 6.248649541372053),
#  (2011, 'Fantasy', 236, 5.810169495768466),
#  (2011, 'Thriller', 666, 5.507957957707368),
#  (2012, 'Action', 666, 5.736036033243747),
#  (2012, 'Comedy', 1774, 5.896899664617042),
#  (2012, 'Drama', 3126, 6.312092130335187),
#  (2012, 'Fantasy', 212, 6.035377359615182),
#  (2012, 'Thriller', 765, 5.500784315003289),
#  (2013, 'Action', 719, 5.655354663460245),
#  (2013, 'Comedy', 1859, 5.954276500497215),
#  (2013, 'Drama', 3510, 6.3232193772609415),
#  (2013, 'Fantasy', 227, 5.725550667304825),
#  (2013, 'Thriller', 935, 5.457540105753404),
#  (2014, 'Action', 776, 5.757345371639605),
#  (2014, 'Comedy', 1970, 5.935329951066051),
#  (2014, 'Drama', 3580, 6.331424588164804),
#  (2014, 'Fantasy', 253, 5.689328060790955),
#  (2014, 'Thriller', 968, 5.5154958710936475),
#  (2015, 'Action', 803, 5.669987545660691),
#  (2015, 'Comedy', 1937, 5.896644297862213),
#  (2015, 'Drama', 3715, 6.277146705932926),
#  (2015, 'Fantasy', 266, 5.850751876831055),
#  (2015, 'Thriller', 993, 5.493756300132921),
#  (2016, 'Action', 884, 5.677828057589035),
#  (2016, 'Comedy', 2019, 5.837543341946992),
#  (2016, 'Drama', 3687, 6.256034720839605),
#  (2016, 'Fantasy', 294, 5.747959191296377),
#  (2016, 'Thriller', 1001, 5.408891105866218),
#  (2017, 'Action', 888, 5.750337846778534),
#  (2017, 'Comedy', 2004, 5.871407184712663),
#  (2017, 'Drama', 3790, 6.284485487258529),
#  (2017, 'Fantasy', 289, 5.860553635032944),
#  (2017, 'Thriller', 1006, 5.388270375150335),
#  (2018, 'Action', 837, 5.64659497344793),
#  (2018, 'Comedy', 2055, 5.742530414541853),
#  (2018, 'Drama', 3768, 6.207457535522505),
#  (2018, 'Fantasy', 317, 5.811671938053817),
#  (2018, 'Thriller', 1003, 5.413359917410587),
#  (2019, 'Action', 839, 5.683194271429787),
#  (2019, 'Comedy', 1896, 5.812763718047223),
#  (2019, 'Drama', 3754, 6.185695262779628),
#  (2019, 'Fantasy', 262, 5.647709936586045),
#  (2019, 'Thriller', 995, 5.364623119962874),
#  (2020, 'Action', 500, 5.555799997568131),
#  (2020, 'Comedy', 1309, 5.787624140201041),
#  (2020, 'Drama', 2622, 6.141151793761439),
#  (2020, 'Fantasy', 240, 5.749166665971279),
#  (2020, 'Thriller', 795, 5.283270441960989),
#  (2021, 'Action', 604, 5.76076158091722),
#  (2021, 'Comedy', 1206, 6.053482585779668),
#  (2021, 'Drama', 2466, 6.418248176333001),
#  (2021, 'Fantasy', 186, 6.0994623720005),
#  (2021, 'Thriller', 804, 5.716417916230301),
#  (2022, 'Action', 48, 6.512499983112018),
#  (2022, 'Comedy', 129, 6.273643408634866),
#  (2022, 'Drama', 200, 6.9260000026226045),
#  (2022, 'Fantasy', 13, 5.861538428526658),
#  (2022, 'Thriller', 89, 6.451685412546222)]

# %%
re_df = re_.DataFrame()

# %%
for g in re_df.genre.unique():
    plt.plot(re_df[re_df.genre == g].start_year,
             re_df[re_df.genre == g].nPerGenre,
             label='n. movies {}'.format(g)
            );
plt.legend(loc='best')

# %%
for g in re_df.genre.unique():
    plt.plot(re_df[re_df.genre == g].start_year,
             re_df[re_df.genre == g].ratPerGenre,
             label='avg ratings {}'.format(g)
            );
plt.legend(loc='best')
